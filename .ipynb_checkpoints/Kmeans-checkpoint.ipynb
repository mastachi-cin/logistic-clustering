# %%
# %pip install numpy
# %pip install matplotlib
# %pip install yellowbrick
# %pip install sklearn
# %pip install sqlalchemy
# %pip install pandas
# %pip install psycopg2
# %pip install flask
import math
import psycopg2
import numpy as np
import matplotlib.pyplot as plt
import yellowbrick 
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score 
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import jsonify
import pandas as pd
import random

# %%
# Database info
database_url = 'postgres://wnjhouloendxny:b027f83c1f0723e6c2c0f515d8bcdcd126d8dbd84cfa0ce97a0826379797f553@ec2-54-152-40-168.compute-1.amazonaws.com:5432/d8207vdcs70hmd'
    
# Database Connection
engine = create_engine(database_url)

# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
Destinations = Base.classes.destinations

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

destinations_data = session.query(Destinations.dest_id, Destinations.address, 
                    Destinations.latitude, Destinations.longitude).all()

# Close session
session.close()

# Convert query results to a dictionary
dest_ls = []
for dest_id, address, latitude, longitude in destinations_data:
    dest_dict = {}
    dest_dict["dest_id"] = dest_id
    dest_dict["address"] = address
    dest_dict["latitude"] = latitude
    dest_dict["longitude"] = longitude
    dest_ls.append(dest_dict)

# Convert list to dataframe
destinations_df = pd.DataFrame(dest_ls)

# Sample for project purpose
seed = 42
size = 1000
size = min(size,1715)
sample = destinations_df.sample(n=size, axis=0, random_state = seed)
sample
# Out:
#       dest_id                                            address   latitude  \
# 522       525  Avilés 403, Nueva Galicia, 64160 Monterrey, N....  25.569804
# 1539     1549  Brazilia 210, Paraje Santa Rosa, 66607 Cd Apod...  25.603419
# 1623     1633  Bulgary 507, Nexxus Esmeralda, 66055 Escobedo ...  25.605014
# 1493     1503  Boulevard Primavera 3508, Contry Tesoro, 64850...  25.602446
# 506       509  Avenida Vista Real 543, Valle Oriente, 66266 S...  25.569491
# ...       ...                                                ...        ...
# 1380     1389  Bosques de Puebla 305, Bosques del Valle 4to S...  25.598311
# 673       676  Balcones 302, Balcones del Valle, San Pedro Ga...  25.575020
# 249       253  Avenida Junco de la Vega 3628, Contry, Monterr...  25.547789
# 1244     1248  Bosques de Ciprés 510, Bosques del Poniente, S...  25.594408
# 1233     1237  Bosques de Chapultepec 204, Bosques del Valle,...  25.593920
#
#        longitude
# 522  -100.244204
# 1539 -100.252868
# 1623 -100.258595
# 1493 -100.271839
# 506  -100.231360
# ...          ...
# 1380 -100.249044
# 673  -100.275886
# 249  -100.230594
# 1244 -100.255620
# 1233 -100.247397
#
# [1000 rows x 4 columns]

# %%
LatLon = []
LatLonLists = []
y_nones = []
lat = list(sample['latitude'])
lon = list(sample['longitude'])


for i in range(len(sample)):
    LatLon.append(lat[i])
    LatLon.append(lon[i])
    LatLonLists.append(LatLon)
    y_nones.append(None)
    LatLon = []
    
X=np.array(LatLonLists)
y=np.array(y_nones)
#print(LatLonLists)
print(X, y)
# Out:
# [[  25.569804   -100.244204  ]
#  [  25.6034186  -100.2528682 ]
#  [  25.60501379 -100.2585949 ]
#  ...
#  [  25.54778893 -100.2305944 ]
#  [  25.594408   -100.2556203 ]
#  [  25.5939204  -100.2473967 ]] [None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None]

# %%
y = y.reshape(len(y),1)
print(y.shape, X.shape)
#print(y)
# Out:
# (1000, 1) (1000, 2)

# %%
cargomax = 20
vehicles = 100
minK = math.ceil(max(len(sample)/cargomax,2))
maxK = min(vehicles,len(sample))
if minK != maxK:
    Ks = range(minK, maxK)
    km = [KMeans(n_clusters=i, random_state = seed) for i in Ks]
    score = [silhouette_score(X,km[i].fit(X).predict(X),random_state=seed) for i in range(len(km))]
    maxscore = np.argmax(score)
    index = min(np.argmax(score) + minK,vehicles)
    
else:
    index = minK

# Use n_clusters=index as the k value
kmeans = KMeans(n_clusters=index, random_state = seed)

minK, maxK, Ks, score, maxscore, index
# Out:
# (10,
#  20,
#  range(10, 20),
#  [0.4605758186492699,
#   0.46278973426132186,
#   0.4664043894158363,
#   0.46485297790769037,
#   0.4667962556214434,
#   0.46614362114107305,
#   0.4719593683815266,
#   0.4643470122057322,
#   0.4567239506485321,
#   0.4609354374885823],
#  6,
#  16)

# %%
# Fit the model to the data
kmeans.fit(X)
# Out:
# KMeans(n_clusters=16, random_state=42)

# %% [markdown]
# Predict the clusters
# predicted_clusters = kmeans.predict(X)
# predicted_clusters

# %%
predicted_clusters = kmeans.predict(X)

# %%
sample['Route'] = predicted_clusters
sample.sort_values(by=['Route'],axis=0,ascending=True,inplace=True)
sample.to_csv()
output_list = sample.to_dict("records")
output_list
# Out:
# [{'dest_id': 49,
#   'address': 'avenida del estado 319,Tecnológico,Monterrey,Nuevo León,México',
#   'latitude': 25.40449748,
#   'longitude': -100.1332163,
#   'Route': 0},
#  {'dest_id': 44,
#   'address': 'Avenida de los Ebanos 822, Arboledas del Virrey, Apodaca, N.L.',
#   'latitude': 25.40153505,
#   'longitude': -100.1385042,
#   'Route': 0},
#  {'dest_id': 57,
#   'address': 'Avenida del Parque 404, Cumbres Oro Sector Le Fontaine, Monterrey, Nuevo Leon',
#   'latitude': 25.4073851,
#   'longitude': -100.1369873,
#   'Route': 0},
#  {'dest_id': 59,
#   'address': 'Avenida Del Pedregal 1604, Pedregal del Valle, San Pedro Garza García, N.L.',
#   'latitude': 25.4084992,
#   'longitude': -100.1358668,
#   'Route': 0},
#  {'dest_id': 42,
#   'address': 'Avenida de los Astros 1338, Barrio Alameda, 64102 Monterrey, N.L.',
#   'latitude': 25.40074716,
#   'longitude': -100.1291538,
#   'Route': 0},
#  {'dest_id': 48,
#   'address': 'Avenida Del Estado 268, Tecnológico, Monterrey, Nuevo Leon',
#   'latitude': 25.40352016,
#   'longitude': -100.1321706,
#   'Route': 0},
#  {'dest_id': 45,
#   'address': 'AVENIDA DEL CORTIJO 4212 RESIDENCIAL LA HACIENDA , MONTERREY',
#   'latitude': 25.40248893,
#   'longitude': -100.1317334,
#   'Route': 0},
#  {'dest_id': 56,
#   'address': 'Avenida del Parque 352, Cumbres Oro Sector Le Fontaine, Monterrey, Nuevo Leon',
#   'latitude': 25.40737215,
#   'longitude': -100.1385888,
#   'Route': 0},
#  {'dest_id': 46,
#   'address': 'Avenida Del Estado 124b, Tecnológico, Monterrey, Nuevo León',
#   'latitude': 25.40270153,
#   'longitude': -100.1334577,
#   'Route': 0},
#  {'dest_id': 43,
#   'address': 'Avenida de los Conquistadores 117, Mirasierra 1er Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.40112891,
#   'longitude': -100.1338193,
#   'Route': 0},
#  {'dest_id': 53,
#   'address': 'Avenida del Paraíso 235, Industrias del Vidrio Oriente, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.4048499,
#   'longitude': -100.13011,
#   'Route': 0},
#  {'dest_id': 50,
#   'address': 'avenida del fin 113,Residencial Punta Esmeralda,Juárez,Nuevo León,México',
#   'latitude': 25.404557,
#   'longitude': -100.1417933,
#   'Route': 0},
#  {'dest_id': 40,
#   'address': 'Avenida de los Astros 101, Barrio San Pedro, 64103, Monterrey, N.L.',
#   'latitude': 25.40035223,
#   'longitude': -100.129653,
#   'Route': 0},
#  {'dest_id': 55,
#   'address': 'Avenida del Parque 103, Cumbres Oro Sector Le Fontaine, Monterrey, Nuevo Leon',
#   'latitude': 25.405695,
#   'longitude': -100.1379576,
#   'Route': 0},
#  {'dest_id': 52,
#   'address': 'Avenida del Paraíso 103., Industrias del Vidrio Oriente, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.40482244,
#   'longitude': -100.1341974,
#   'Route': 0},
#  {'dest_id': 1424,
#   'address': 'Bosques de Vistancia, Sierra de la Silla, Villas La Rioja, Monterrey, Nuevo Leon',
#   'latitude': 25.60026135,
#   'longitude': -100.25983,
#   'Route': 1},
#  {'dest_id': 1370,
#   'address': 'Bosques de Olmos 26, Villas del Valle, San Pedro Garza García, N.L.',
#   'latitude': 25.5978592,
#   'longitude': -100.2580263,
#   'Route': 1},
#  {'dest_id': 1632,
#   'address': 'Bulgaria 431, Nuevo Amanecer, Apodaca, N.L.',
#   'latitude': 25.60501362,
#   'longitude': -100.2585947,
#   'Route': 1},
#  {'dest_id': 1276,
#   'address': 'Bosques de Cuernavaca 525, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5949978,
#   'longitude': -100.2522207,
#   'Route': 1},
#  {'dest_id': 1661,
#   'address': 'Burgos 3805,Las Torres,Monterrey,Nuevo León,México',
#   'latitude': 25.60542996,
#   'longitude': -100.2531143,
#   'Route': 1},
#  {'dest_id': 1566,
#   'address': 'Brest 227, Bosques de Las Cumbres, 64619 Monterrey, N.L., México',
#   'latitude': 25.6039554,
#   'longitude': -100.252146,
#   'Route': 1},
#  {'dest_id': 1292,
#   'address': 'bosques de la huasteca 471,INFONAVIT la Huasteca,Santa Catarina,Nuevo León,México',
#   'latitude': 25.5955369,
#   'longitude': -100.2556816,
#   'Route': 1},
#  {'dest_id': 1554,
#   'address': 'Brest 115, Bosques de Las Cumbres, 64619 Monterrey, N.L.',
#   'latitude': 25.60353589,
#   'longitude': -100.2630782,
#   'Route': 1},
#  {'dest_id': 1659,
#   'address': 'Burgos 3804, Las Torres, 64930 Monterrey, N.L.',
#   'latitude': 25.6053516,
#   'longitude': -100.2624442,
#   'Route': 1},
#  {'dest_id': 1291,
#   'address': 'Bosques de La Huasteca 307, Bosques del Valle 4to Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.595531,
#   'longitude': -100.247693,
#   'Route': 1},
#  {'dest_id': 1232,
#   'address': 'Bosques de Canadá 205, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5937859,
#   'longitude': -100.2474605,
#   'Route': 1},
#  {'dest_id': 1678,
#   'address': 'Bustamante 140, Valle de San Agustín, 66278 San Pedro Garza García, N.L.',
#   'latitude': 25.6055582,
#   'longitude': -100.2636247,
#   'Route': 1},
#  {'dest_id': 1159,
#   'address': 'Bosque de Cenizos 219, Cima del Bosque, Nuevo Leon',
#   'latitude': 25.58935509,
#   'longitude': -100.2577592,
#   'Route': 1},
#  {'dest_id': 1402,
#   'address': 'bosques de saigon,Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5988545,
#   'longitude': -100.2552405,
#   'Route': 1},
#  {'dest_id': 1588,
#   'address': 'Briviesca',
#   'latitude': 25.6041932,
#   'longitude': -100.2630251,
#   'Route': 1},
#  {'dest_id': 1275,
#   'address': 'Bosques de Cuernavaca 518, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5949978,
#   'longitude': -100.2522207,
#   'Route': 1},
#  {'dest_id': 1459,
#   'address': 'Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.6009914,
#   'longitude': -100.253888,
#   'Route': 1},
#  {'dest_id': 1487,
#   'address': 'Boulevard Botánica 2201, Valle del Campestre, San Pedro Garza García, N.L.',
#   'latitude': 25.6017567,
#   'longitude': -100.2521934,
#   'Route': 1},
#  {'dest_id': 1319,
#   'address': 'Bosques de Los Alamos 406, Bosques de Anáhuac, 66463 San Nicolás de los Garza, N.L.',
#   'latitude': 25.5965786,
#   'longitude': -100.2514828,
#   'Route': 1},
#  {'dest_id': 1601,
#   'address': 'bruno traven 3284,Altavista Sur,Monterrey,Nuevo León,México',
#   'latitude': 25.6043862,
#   'longitude': -100.2548973,
#   'Route': 1},
#  {'dest_id': 1248,
#   'address': 'Bosques de Ciprés 510, Bosques del Poniente, Santa Catarina, N.L., México',
#   'latitude': 25.594408,
#   'longitude': -100.2556203,
#   'Route': 1},
#  {'dest_id': 1233,
#   'address': 'Bosques de Canadá 312, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5937859,
#   'longitude': -100.2474605,
#   'Route': 1},
#  {'dest_id': 1449,
#   'address': 'Bosques del Peñón 2223, Bosques de La Pastora 2o Sector, Guadalupe, Nuevo Leon',
#   'latitude': 25.6008063,
#   'longitude': -100.2620499,
#   'Route': 1},
#  {'dest_id': 1665,
#   'address': 'Burgos 4112, Las Torres, 64930 Monterrey, N.L.',
#   'latitude': 25.60547578,
#   'longitude': -100.2567921,
#   'Route': 1},
#  {'dest_id': 1377,
#   'address': 'Bosques de Pirineos 406, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5979914,
#   'longitude': -100.2619088,
#   'Route': 1},
#  {'dest_id': 1614,
#   'address': 'Bugambilia 214, Villas de Santa Rosa, N.L.',
#   'latitude': 25.60457008,
#   'longitude': -100.2576633,
#   'Route': 1},
#  {'dest_id': 1243,
#   'address': 'Bosques de Chapultepec 409, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5942906,
#   'longitude': -100.2485137,
#   'Route': 1},
#  {'dest_id': 1427,
#   'address': 'Bosques del Canadá 628, Bosques de Anáhuac, 66463 San Nicolás de los Garza, N.L.',
#   'latitude': 25.60029461,
#   'longitude': -100.2567891,
#   'Route': 1},
#  {'dest_id': 1461,
#   'address': 'Bosques el Edén #203,Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.6009914,
#   'longitude': -100.2538876,
#   'Route': 1},
#  {'dest_id': 1410,
#   'address': 'Bosques de Siberia 204, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., Mexico, San Pedro Garza García',
#   'latitude': 25.5992465,
#   'longitude': -100.2624068,
#   'Route': 1},
#  {'dest_id': 1322,
#   'address': 'Bosques de Los Alamos 415, Bosques de Anáhuac, San Nicolás de los Garza, N.L., México',
#   'latitude': 25.5966266,
#   'longitude': -100.2504041,
#   'Route': 1},
#  {'dest_id': 1214,
#   'address': 'BOSQUES',
#   'latitude': 25.5925091,
#   'longitude': -100.2531995,
#   'Route': 1},
#  {'dest_id': 1394,
#   'address': 'Bosques de Puebla 318, Bosques del Valle 4to Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.598718,
#   'longitude': -100.248449,
#   'Route': 1},
#  {'dest_id': 1272,
#   'address': 'Bosques de Cuernavaca 516, Bosques del Valle 3ER Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.594964,
#   'longitude': -100.249457,
#   'Route': 1},
#  {'dest_id': 1210,
#   'address': 'BOSQUES',
#   'latitude': 25.59227131,
#   'longitude': -100.2488935,
#   'Route': 1},
#  {'dest_id': 1426,
#   'address': 'Bosques del Alamo 306, Bosques del Valle 1er Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.60027587,
#   'longitude': -100.2596382,
#   'Route': 1},
#  {'dest_id': 1550,
#   'address': 'Brazilia 212, Paraje Santa Rosa, 66607 Cd Apodaca, N.L., México, Ciudad Apodaca',
#   'latitude': 25.6034186,
#   'longitude': -100.2528682,
#   'Route': 1},
#  {'dest_id': 1259,
#   'address': 'Bosques de Cuernavaca 503, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5947269,
#   'longitude': -100.247422,
#   'Route': 1},
#  {'dest_id': 1238,
#   'address': 'Bosques de Chapultepec 304, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5940368,
#   'longitude': -100.249048,
#   'Route': 1},
#  {'dest_id': 1660,
#   'address': 'Burgos 3805, Las Torres, 64930 Monterrey, N.L., México',
#   'latitude': 25.6054006,
#   'longitude': -100.2551046,
#   'Route': 1},
#  {'dest_id': 1304,
#   'address': 'Bosques de La Sierra 321, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.5960121,
#   'longitude': -100.2573841,
#   'Route': 1},
#  {'dest_id': 1508,
#   'address': 'boulevard primavera 3530-6,Contry Tesoro,Monterrey,Nuevo León,México',
#   'latitude': 25.60248534,
#   'longitude': -100.2522533,
#   'Route': 1},
#  {'dest_id': 1320,
#   'address': 'Bosques de Los Alamos 412, Bosques de Anáhuac, 66463 San Nicolás de los Garza, N.L.',
#   'latitude': 25.596579,
#   'longitude': -100.251483,
#   'Route': 1},
#  {'dest_id': 1669,
#   'address': 'Burgos 4144, Las Torres, 64930 Monterrey, N.L., México',
#   'latitude': 25.6055084,
#   'longitude': -100.259169,
#   'Route': 1},
#  {'dest_id': 1296,
#   'address': 'Bosques de la pastora 2228, Bosques de la pastora, Guadalupe. Entre bosques de los Álamos/ medio skittles',
#   'latitude': 25.5955898,
#   'longitude': -100.2486324,
#   'Route': 1},
#  {'dest_id': 1218,
#   'address': 'bosques abetos 225, cima del bosque, monterrey nuevo leon',
#   'latitude': 25.59280289,
#   'longitude': -100.2533027,
#   'Route': 1},
#  {'dest_id': 1168,
#   'address': 'Bosque de los sabinos 205, bosques de valle alto, monterrey NL',
#   'latitude': 25.58971056,
#   'longitude': -100.2534437,
#   'Route': 1},
#  {'dest_id': 1542,
#   'address': 'Brasilia 202,Paraje Santa Rosa,Apodaca,Nuevo León,México',
#   'latitude': 25.6032993,
#   'longitude': -100.2549998,
#   'Route': 1},
#  {'dest_id': 1354,
#   'address': 'Bosques de Nórdicos 304, Bosques del Valle 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.59750482,
#   'longitude': -100.2590389,
#   'Route': 1},
#  {'dest_id': 1287,
#   'address': 'Bosques de Granados 325, Bosques del Valle Ampliación 5o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.59524,
#   'longitude': -100.247835,
#   'Route': 1},
#  {'dest_id': 1612,
#   'address': 'Buenos Aires 229, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.60455314,
#   'longitude': -100.2570658,
#   'Route': 1},
#  {'dest_id': 1398,
#   'address': 'Bosques de Puebla 353, Bosques del valle,San Pedro',
#   'latitude': 25.598776,
#   'longitude': -100.2486848,
#   'Route': 1},
#  {'dest_id': 1385,
#   'address': 'Bosques de Pirineos 508, Bosques del Valle 3ER Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.59823127,
#   'longitude': -100.2626675,
#   'Route': 1},
#  {'dest_id': 1646,
#   'address': 'Burdeos 132, Cerradas de Concordia, 66609 Cd Apodaca, N.L., México, Ciudad Apodaca',
#   'latitude': 25.6051771,
#   'longitude': -100.2559667,
#   'Route': 1},
#  {'dest_id': 1608,
#   'address': 'Bucarest 1227,El Refugio Sector 2,San Nicolás de los Garza,Nuevo León,México',
#   'latitude': 25.6045376,
#   'longitude': -100.2521324,
#   'Route': 1},
#  {'dest_id': 1423,
#   'address': 'Bosques de Vistancia, Sierra de la Silla, Villas La Rioja, Monterrey, N.L.',
#   'latitude': 25.60024472,
#   'longitude': -100.2608848,
#   'Route': 1},
#  {'dest_id': 1636,
#   'address': 'Bura 300, San Patricio 4o Sector, 66270 San Pedro Garza García, N.L.',
#   'latitude': 25.6050493,
#   'longitude': -100.2524853,
#   'Route': 1},
#  {'dest_id': 1630,
#   'address': 'Bulgaria 210, Nuevo Amanecer, Ciudad Apodaca, Nuevo Leon',
#   'latitude': 25.604996,
#   'longitude': -100.252487,
#   'Route': 1},
#  {'dest_id': 1539,
#   'address': 'Brasil 304, Vista Hermosa, Monterrey, Nuevo Leon',
#   'latitude': 25.60327359,
#   'longitude': -100.2558008,
#   'Route': 1},
#  {'dest_id': 1239,
#   'address': 'Bosques de Chapultepec 304, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5940886,
#   'longitude': -100.2462218,
#   'Route': 1},
#  {'dest_id': 1267,
#   'address': 'Bosques de Cuernavaca 511, Bosques del Valle 3ER Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5948579,
#   'longitude': -100.2454222,
#   'Route': 1},
#  {'dest_id': 1673,
#   'address': 'Burgos 6605, Cumbres de Santa Clara, 64349 Monterrey, N.L., México',
#   'latitude': 25.6055276,
#   'longitude': -100.2595182,
#   'Route': 1},
#  {'dest_id': 1584,
#   'address': 'Brisa del Rio 101, Valle Alto, Monterrey, Nuevo León',
#   'latitude': 25.60417839,
#   'longitude': -100.2564632,
#   'Route': 1},
#  {'dest_id': 1568,
#   'address': 'Brest 230, Bosques de Las Cumbres, 64619 Monterrey, N.L., México',
#   'latitude': 25.60398502,
#   'longitude': -100.2565291,
#   'Route': 1},
#  {'dest_id': 1414,
#   'address': 'Bosques de Tahiti 524, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.59950514,
#   'longitude': -100.2553266,
#   'Route': 1},
#  {'dest_id': 1336,
#   'address': 'Bosques de Los Fresnos 2333, Bosques de La Pastora 3ER Sector, Guadalupe, N.L.',
#   'latitude': 25.5971796,
#   'longitude': -100.2578781,
#   'Route': 1},
#  {'dest_id': 1346,
#   'address': 'Bosques de Los Pirineos 213, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.5974135,
#   'longitude': -100.255994,
#   'Route': 1},
#  {'dest_id': 1368,
#   'address': 'Bosques de Olmos 214, Bosque de San Miguel, Apodaca, N.L.',
#   'latitude': 25.5978119,
#   'longitude': -100.2592674,
#   'Route': 1},
#  {'dest_id': 1353,
#   'address': 'Bosques de Nogales 253, Bosque de San Miguel, Apodaca, N.L.',
#   'latitude': 25.59750452,
#   'longitude': -100.2590386,
#   'Route': 1},
#  {'dest_id': 1189,
#   'address': 'Bosque Flamenco 505, Las Lomas Sector Bosques, N.L.',
#   'latitude': 25.59112769,
#   'longitude': -100.2596713,
#   'Route': 1},
#  {'dest_id': 1572,
#   'address': 'Brest 235, Bosques de Las Cumbres, Monterrey, Nuevo Leon',
#   'latitude': 25.60403007,
#   'longitude': -100.2538579,
#   'Route': 1},
#  {'dest_id': 1452,
#   'address': 'Bosques del Pinal 2622, Bosques de La Pastora 3ER Sector, Guadalupe, Nuevo Leon',
#   'latitude': 25.6008347,
#   'longitude': -100.2541976,
#   'Route': 1},
#  {'dest_id': 1702,
#   'address': 'C. Jean Paul Sartre 922, Colinas de Liverpool, Monterrey, N.L.',
#   'latitude': 25.6060165,
#   'longitude': -100.2595494,
#   'Route': 1},
#  {'dest_id': 1288,
#   'address': 'Bosques de Irlanda 201, Zona Bosques del Valle, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5952424,
#   'longitude': -100.2477776,
#   'Route': 1},
#  {'dest_id': 1209,
#   'address': 'bosques',
#   'latitude': 25.59226088,
#   'longitude': -100.2484665,
#   'Route': 1},
#  {'dest_id': 1277,
#   'address': 'Bosques de encino 1016 bosques del valle, San Pedro Garza Garcia',
#   'latitude': 25.5950485,
#   'longitude': -100.2527217,
#   'Route': 1},
#  {'dest_id': 1599,
#   'address': 'Bruno traven 3284,Altavista Sur,Monterrey,Nuevo León,México',
#   'latitude': 25.6043199,
#   'longitude': -100.2544807,
#   'Route': 1},
#  {'dest_id': 1504,
#   'address': 'Boulevard Primavera 3512, Contry Tesoro, Monterrey, N.L., México',
#   'latitude': 25.60245497,
#   'longitude': -100.2530997,
#   'Route': 1},
#  {'dest_id': 1369,
#   'address': 'Bosques de Olmos 26, Villas del Valle, 66288 San Pedro Garza García, N.L., México',
#   'latitude': 25.5978564,
#   'longitude': -100.2496996,
#   'Route': 1},
#  {'dest_id': 1652,
#   'address': 'Burdeos 5109, Las Torres, 64930 Monterrey, N.L.',
#   'latitude': 25.60524976,
#   'longitude': -100.2571872,
#   'Route': 1},
#  {'dest_id': 1685,
#   'address': 'Bustamante 516, Eulalio Villarreal Ayala, General Escobedo, Nuevo Leon',
#   'latitude': 25.6056609,
#   'longitude': -100.254492,
#   'Route': 1},
#  {'dest_id': 1674,
#   'address': 'Burócratas 500A, Cumbres 2o. Sector Secc C, 64610 Monterrey, N.L., México',
#   'latitude': 25.6055305,
#   'longitude': -100.2522558,
#   'Route': 1},
#  {'dest_id': 1355,
#   'address': 'Bosques de Nórdicos 332, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.59750499,
#   'longitude': -100.2590391,
#   'Route': 1},
#  {'dest_id': 1578,
#   'address': 'Brisa del Campo 105, Monterrey, N.L., México',
#   'latitude': 25.6040687,
#   'longitude': -100.2544225,
#   'Route': 1},
#  {'dest_id': 1234,
#   'address': 'Bosques de Catemaco 301, Bosques del Valle 4to Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5938331,
#   'longitude': -100.2555618,
#   'Route': 1},
#  {'dest_id': 1698,
#   'address': 'C. de Los 4 Parques 2226, Cumbres 2o. Sector Secc C, 64610 Monterrey, N.L., Mexico',
#   'latitude': 25.6059559,
#   'longitude': -100.258083,
#   'Route': 1},
#  {'dest_id': 1609,
#   'address': 'Bucarest, Sector Irlandés Sur, Privadas de Anáhuac Sector Irlandes, Cd Gral Escobedo, N.L., México, Ciudad General Escobedo',
#   'latitude': 25.6045376,
#   'longitude': -100.2521324,
#   'Route': 1},
#  {'dest_id': 1496,
#   'address': 'boulevard milenium 5104, aeropuerto 66600',
#   'latitude': 25.60211949,
#   'longitude': -100.2622559,
#   'Route': 1},
#  {'dest_id': 1246,
#   'address': 'bosques de chapultepec,Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5943617,
#   'longitude': -100.2559048,
#   'Route': 1},
#  {'dest_id': 1553,
#   'address': 'BRECHA 306, LA ENRAMADA 1 SAN NICOLAS, SAN NICOLAS NL',
#   'latitude': 25.60353589,
#   'longitude': -100.2630782,
#   'Route': 1},
#  {'dest_id': 1293,
#   'address': 'bosques de la loma 2230,Bosques de la Pastora,Guadalupe,Nuevo León,México',
#   'latitude': 25.5955568,
#   'longitude': -100.2482762,
#   'Route': 1},
#  {'dest_id': 1357,
#   'address': 'Bosques de Nórdicos 334, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.597553,
#   'longitude': -100.257451,
#   'Route': 1},
#  {'dest_id': 1395,
#   'address': 'Bosques de Puebla 322, Bosques del Valle 4to Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.59872837,
#   'longitude': -100.2550393,
#   'Route': 1},
#  {'dest_id': 1294,
#   'address': 'Bosques de la Loma 2313, Bosques de La Pastora 3ER Sector, Guadalupe, N.L., México, Guadalupe',
#   'latitude': 25.5955568,
#   'longitude': -100.2482762,
#   'Route': 1},
#  {'dest_id': 1596,
#   'address': 'Bruno Traven 3254, Alta Vista Sur, 64740 Monterrey, N.L.',
#   'latitude': 25.6042978,
#   'longitude': -100.2536125,
#   'Route': 1},
#  {'dest_id': 1522,
#   'address': 'Boulevard Puerta del Sol 725, Colinas de San Jerónimo 5o. Sector, Monterrey, Nuevo Leon',
#   'latitude': 25.6028773,
#   'longitude': -100.2592403,
#   'Route': 1},
#  {'dest_id': 1520,
#   'address': 'Boulevard puerta del sol 650, colinas de san jeronimo, monterrey NL',
#   'latitude': 25.6028221,
#   'longitude': -100.2540236,
#   'Route': 1},
#  {'dest_id': 1571,
#   'address': 'Brest 235, Bosques de Las Cumbres, 64619 Monterrey, N.L.',
#   'latitude': 25.6040283,
#   'longitude': -100.255593,
#   'Route': 1},
#  {'dest_id': 1624,
#   'address': 'Bugambilias 736, Ebanos V, Ciudad Apodaca, N.L.',
#   'latitude': 25.6047868,
#   'longitude': -100.256836,
#   'Route': 1},
#  {'dest_id': 1627,
#   'address': 'bugambilias del monte 225,Bugambilias de la Sierra,Guadalupe,Nuevo León,México',
#   'latitude': 25.604898,
#   'longitude': -100.253733,
#   'Route': 1},
#  {'dest_id': 1389,
#   'address': 'Bosques de Puebla 305, Bosques del Valle 4to Sector, 66250 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.5983107,
#   'longitude': -100.2490436,
#   'Route': 1},
#  {'dest_id': 1642,
#   'address': 'Bura 446, San Patricio 4o Sector, 66270 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.605093,
#   'longitude': -100.252497,
#   'Route': 1},
#  {'dest_id': 1425,
#   'address': 'Bosques del Alamo 306, Bosques del Valle 1er Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.6002687,
#   'longitude': -100.2599468,
#   'Route': 1},
#  {'dest_id': 1401,
#   'address': 'Bosques de Saigan 206, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5988545,
#   'longitude': -100.2552405,
#   'Route': 1},
#  {'dest_id': 1565,
#   'address': 'Brest 217, Bosques de Las Cumbres, 64619 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.6038769,
#   'longitude': -100.2626017,
#   'Route': 1},
#  {'dest_id': 1512,
#   'address': 'Boulevard Puerta del Sol 201, Colinas de San Jerónimo 1o. Sector, Monterrey, Nuevo Leon',
#   'latitude': 25.60261,
#   'longitude': -100.262492,
#   'Route': 1},
#  {'dest_id': 1699,
#   'address': 'C. de Los 4 Parques 2226, Cumbres 2o. Sector Secc C, 64610 Monterrey, N.L., Mexico',
#   'latitude': 25.60596088,
#   'longitude': -100.2597705,
#   'Route': 1},
#  {'dest_id': 1284,
#   'address': 'Bosques de Encinos 915, Bosques del Valle Ampliación 5o Sector, 66250 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.595205,
#   'longitude': -100.247539,
#   'Route': 1},
#  {'dest_id': 1332,
#   'address': 'Bosques de Los Fresnos 2318, Bosques de La Pastora 3ER Sector, Guadalupe, N.L., México',
#   'latitude': 25.59704508,
#   'longitude': -100.2624961,
#   'Route': 1},
#  {'dest_id': 1212,
#   'address': 'Bosques',
#   'latitude': 25.5923646,
#   'longitude': -100.2559256,
#   'Route': 1},
#  {'dest_id': 1610,
#   'address': 'Bucheli 2508, Contry La Silla 8o Sector, 67173 Guadalupe, N.L., México, Guadalupe',
#   'latitude': 25.6045376,
#   'longitude': -100.2521324,
#   'Route': 1},
#  {'dest_id': 1236,
#   'address': 'Bosques de Catemaco 316, Bosques del Valle 4to Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.59387483,
#   'longitude': -100.2469814,
#   'Route': 1},
#  {'dest_id': 1458,
#   'address': 'bosques del valle,Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.60099125,
#   'longitude': -100.2538876,
#   'Route': 1},
#  {'dest_id': 1265,
#   'address': 'Bosques de Cuernavaca 511, Bosques del Valle 3ER Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.59477894,
#   'longitude': -100.2461144,
#   'Route': 1},
#  {'dest_id': 1462,
#   'address': 'Bosques Mexicanos 116, Zona Bosques del Valle, 66250 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.6010381,
#   'longitude': -100.2622919,
#   'Route': 1},
#  {'dest_id': 1289,
#   'address': 'bosques de la huasteca 2501,Bosques de la Pastora,Guadalupe,Nuevo León,México',
#   'latitude': 25.59546519,
#   'longitude': -100.2482959,
#   'Route': 1},
#  {'dest_id': 1299,
#   'address': 'Bosques de La Sierra 319, Bosques del Valle 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5959889,
#   'longitude': -100.2472263,
#   'Route': 1},
#  {'dest_id': 1262,
#   'address': 'Bosques de Cuernavaca 510, Bosques del Valle 3ER Sector, San Pedro Garza García, N.L., México',
#   'latitude': 25.59474614,
#   'longitude': -100.2488708,
#   'Route': 1},
#  {'dest_id': 1475,
#   'address': 'Bosques Nordicos 320, Bosques del Valle, San Pedro.',
#   'latitude': 25.6012399,
#   'longitude': -100.2614146,
#   'Route': 1},
#  {'dest_id': 1220,
#   'address': 'Bosques de Alamos 112, Bosques de Satélite, 64979 Monterrey, N.L.',
#   'latitude': 25.5928853,
#   'longitude': -100.2525337,
#   'Route': 1},
#  {'dest_id': 1587,
#   'address': 'Brisas del Mar 149, Brisas de valle Alto, Monterrey',
#   'latitude': 25.60419304,
#   'longitude': -100.263025,
#   'Route': 1},
#  {'dest_id': 1421,
#   'address': 'Bosques de Viena 750, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.6000167,
#   'longitude': -100.2555764,
#   'Route': 1},
#  {'dest_id': 1256,
#   'address': 'Bosques de Cuernavaca 407, Bosques del Valle 3ER Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.5946714,
#   'longitude': -100.246591,
#   'Route': 1},
#  {'dest_id': 1476,
#   'address': 'Bosques Noruegos 633, Bosques de Anáhuac, 66463 San Nicolás de los Garza, N.L., Mexico',
#   'latitude': 25.60124508,
#   'longitude': -100.2567068,
#   'Route': 1},
#  {'dest_id': 1407,
#   'address': 'Bosques de Sauces 638, Bosques del Poniente, Santa Catarina, Nuevo Leon',
#   'latitude': 25.59909134,
#   'longitude': -100.2553412,
#   'Route': 1},
#  {'dest_id': 1681,
#   'address': 'Bustamante 148, Valle de San Agustín, 66278 San Pedro Garza García, N.L., México',
#   'latitude': 25.6055992,
#   'longitude': -100.259328,
#   'Route': 1},
#  {'dest_id': 1537,
#   'address': 'Brasil 255, Vista Hermosa, 64620 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.6032287,
#   'longitude': -100.2530407,
#   'Route': 1},
#  {'dest_id': 1604,
#   'address': 'bublin 5210,Las Torres,Monterrey,Nuevo León,México',
#   'latitude': 25.6044177,
#   'longitude': -100.255423,
#   'Route': 1},
#  {'dest_id': 1362,
#   'address': 'Bosques de Noruega 832, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, Nuevo León, México',
#   'latitude': 25.5976552,
#   'longitude': -100.2573601,
#   'Route': 1},
#  {'dest_id': 1235,
#   'address': 'Bosques de Catemaco 315, Bosques del Valle 4to Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.59384566,
#   'longitude': -100.2470993,
#   'Route': 1},
#  {'dest_id': 1397,
#   'address': 'Bosques de Puebla 337, Bosques del Valle 4to Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.59874151,
#   'longitude': -100.2610647,
#   'Route': 1},
#  {'dest_id': 1527,
#   'address': 'Boulevard San Francisco 815, Cabecera Municipal (Apodaca), Residencial San Francisco, Apodaca, N.L.',
#   'latitude': 25.60299693,
#   'longitude': -100.2560573,
#   'Route': 1},
#  {'dest_id': 1582,
#   'address': 'Brisa del Mar 143, Monterrey, Nuevo León',
#   'latitude': 25.6041651,
#   'longitude': -100.2576706,
#   'Route': 1},
#  {'dest_id': 1631,
#   'address': 'Bulgaria 431, Nuevo Amanecer, Apodaca, N.L.',
#   'latitude': 25.6049983,
#   'longitude': -100.2621047,
#   'Route': 1},
#  {'dest_id': 1559,
#   'address': 'Brest 137, Bosques de Las Cumbres, 64619 Monterrey, N.L.',
#   'latitude': 25.6037651,
#   'longitude': -100.2536703,
#   'Route': 1},
#  {'dest_id': 1408,
#   'address': 'Bosques de Sauces 664, Bosques del Poniente, 66362 Santa Catarina, N.L.',
#   'latitude': 25.59909151,
#   'longitude': -100.2553413,
#   'Route': 1},
#  {'dest_id': 1662,
#   'address': 'Burgos 3829, Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.6054301,
#   'longitude': -100.2531146,
#   'Route': 1},
#  {'dest_id': 1300,
#   'address': 'Bosques de La Sierra 320, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.59599901,
#   'longitude': -100.245581,
#   'Route': 1},
#  {'dest_id': 1656,
#   'address': 'Burdeos 5109, Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.6052812,
#   'longitude': -100.2620578,
#   'Route': 1},
#  {'dest_id': 1560,
#   'address': 'Brest 137, Bosques de Las Cumbres, Monterrey, N.L.',
#   'latitude': 25.6038027,
#   'longitude': -100.2544642,
#   'Route': 1},
#  {'dest_id': 1309,
#   'address': 'Bosques de La Silla 2221, Bosques de La Pastora 2o Sector, Guadalupe, N.L., México',
#   'latitude': 25.5961004,
#   'longitude': -100.2458745,
#   'Route': 1},
#  {'dest_id': 1635,
#   'address': 'Bura 100, San Patricio 4o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.6050222,
#   'longitude': -100.2572132,
#   'Route': 1},
#  {'dest_id': 1361,
#   'address': 'Bosques de Noruega 822, Bosques del Valle 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.597618,
#   'longitude': -100.251535,
#   'Route': 1},
#  {'dest_id': 1514,
#   'address': 'Boulevard Puerta del Sol 205, Colinas de San Jerónimo 1o. Sector, Monterrey, Nuevo Leon, Mexico',
#   'latitude': 25.60263289,
#   'longitude': -100.2544658,
#   'Route': 1},
#  {'dest_id': 1540,
#   'address': 'Brasil 313, Vista Hermosa, 64620 Monterrey, N.L.',
#   'latitude': 25.6032952,
#   'longitude': -100.2521271,
#   'Route': 1},
#  {'dest_id': 1611,
#   'address': 'Buenos Aires 104, Renaceres Residencial, Ciudad Apodaca, Nuevo León',
#   'latitude': 25.604545,
#   'longitude': -100.2562117,
#   'Route': 1},
#  {'dest_id': 1344,
#   'address': 'Bosques de Los Pirineos 213, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.5973571,
#   'longitude': -100.2498419,
#   'Route': 1},
#  {'dest_id': 1274,
#   'address': 'Bosques de Cuernavaca 516, Bosques del Valle 3ER Sector, San Pedro Garza García, Nuevo León',
#   'latitude': 25.59497911,
#   'longitude': -100.256574,
#   'Route': 1},
#  {'dest_id': 1498,
#   'address': 'boulevard primavera 2900,La Primavera,Monterrey,Nuevo León,México',
#   'latitude': 25.6021851,
#   'longitude': -100.2548206,
#   'Route': 1},
#  {'dest_id': 1321,
#   'address': 'Bosques de Los Alamos 412, Bosques de Anáhuac, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.596591,
#   'longitude': -100.2502,
#   'Route': 1},
#  {'dest_id': 1349,
#   'address': 'Bosques de Los Pirineos 502, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5974278,
#   'longitude': -100.2518059,
#   'Route': 1},
#  {'dest_id': 1597,
#   'address': 'Bruno Traven 3256, Alta Vista Sur, 64740 Monterrey, N.L.',
#   'latitude': 25.6042978,
#   'longitude': -100.2536125,
#   'Route': 1},
#  {'dest_id': 1253,
#   'address': 'Bosques de Ciprés 671, Bosques del Poniente, 66362 Santa Catarina, N.L., México',
#   'latitude': 25.5945433,
#   'longitude': -100.2475813,
#   'Route': 1},
#  {'dest_id': 1670,
#   'address': 'Burgos 4144, Las Torres, 64930 Monterrey, N.L., México',
#   'latitude': 25.60551129,
#   'longitude': -100.259283,
#   'Route': 1},
#  {'dest_id': 1606,
#   'address': 'Bucarest 1227, El Refugio 2do Sector, 66430 San Nicolás de los Garza, N.L., Mexico',
#   'latitude': 25.6044448,
#   'longitude': -100.2624471,
#   'Route': 1},
#  {'dest_id': 1622,
#   'address': 'Bugambilias 353, Los Girasoles 1er Sector, Ciudad General Escobedo, N.L., Los Girasoles 1er Sector, Ciudad General Escobedo, N.L.',
#   'latitude': 25.6047231,
#   'longitude': -100.2543385,
#   'Route': 1},
#  {'dest_id': 1703,
#   'address': 'C. Jerónimo Treviño 314, Centro, 66400 San Nicolás de los Garza, N.L.',
#   'latitude': 25.60601863,
#   'longitude': -100.2572891,
#   'Route': 1},
#  {'dest_id': 1629,
#   'address': 'Bugambilias, Residencial las Margaritas, Santa Catarina, N.L.',
#   'latitude': 25.60489829,
#   'longitude': -100.2537334,
#   'Route': 1},
#  {'dest_id': 1311,
#   'address': 'Bosques de La Silla 2249, Bosques de La Pastora 2o Sector, Guadalupe, N.L.',
#   'latitude': 25.59619542,
#   'longitude': -100.2608835,
#   'Route': 1},
#  {'dest_id': 1663,
#   'address': 'Burgos 4024, Las Torres, 64930 Monterrey, N.L.',
#   'latitude': 25.6054422,
#   'longitude': -100.2597456,
#   'Route': 1},
#  {'dest_id': 1329,
#   'address': 'Bosques de Los Fresnos 2222, Bosques de La Pastora 1er Sector, 67176 Guadalupe, N.L.',
#   'latitude': 25.596822,
#   'longitude': -100.249805,
#   'Route': 1},
#  {'dest_id': 1255,
#   'address': 'Bosques de Cuernavaca 403, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5946714,
#   'longitude': -100.246591,
#   'Route': 1},
#  {'dest_id': 1237,
#   'address': 'Bosques de Chapultepec 204, Bosques del Valle, San Pedro Garza Garcia',
#   'latitude': 25.5939204,
#   'longitude': -100.2473967,
#   'Route': 1},
#  {'dest_id': 1356,
#   'address': 'Bosques de Nórdicos 332, Bosques del Valle 5o Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.5975203,
#   'longitude': -100.2595616,
#   'Route': 1},
#  {'dest_id': 1472,
#   'address': 'Bosques Negro 810, Bosques del Valle 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.6011956,
#   'longitude': -100.2601638,
#   'Route': 1},
#  {'dest_id': 1273,
#   'address': 'Bosques de Cuernavaca 516, Bosques del Valle 3ER Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.594976,
#   'longitude': -100.252183,
#   'Route': 1},
#  {'dest_id': 1208,
#   'address': 'bosques',
#   'latitude': 25.59223955,
#   'longitude': -100.2488687,
#   'Route': 1},
#  {'dest_id': 1467,
#   'address': 'Bosques Mexicanos 122, Zona Bosques del Valle, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.6011332,
#   'longitude': -100.2615703,
#   'Route': 1},
#  {'dest_id': 1400,
#   'address': 'Bosques de Saigan 190, Jerónimo Siller, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.59883248,
#   'longitude': -100.2489582,
#   'Route': 1},
#  {'dest_id': 1412,
#   'address': 'Bosques de Siberia 225, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.59943892,
#   'longitude': -100.2609867,
#   'Route': 1},
#  {'dest_id': 1521,
#   'address': 'Boulevard Puerta del Sol 702, Colinas de San Jerónimo 1o. Sector, Monterrey, N.L., México',
#   'latitude': 25.602862,
#   'longitude': -100.254031,
#   'Route': 1},
#  {'dest_id': 1479,
#   'address': 'Boticelli 200, Renacimiento, Colonia Miguel Hidalgo, 64925 Monterrey, N.L., México',
#   'latitude': 25.6013652,
#   'longitude': -100.2536753,
#   'Route': 1},
#  {'dest_id': 1575,
#   'address': 'Brianzzas Residencial Livorno, Avenida Union, Sin Nombre de Colonia 10, General Escobedo, Nuevo Leon',
#   'latitude': 25.6040602,
#   'longitude': -100.2575054,
#   'Route': 1},
#  {'dest_id': 1306,
#   'address': 'Bosques de La Sierra 329, Bosques del Valle 5o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.596049,
#   'longitude': -100.246549,
#   'Route': 1},
#  {'dest_id': 1574,
#   'address': 'Bretaña, Nuevo León, México',
#   'latitude': 25.6040602,
#   'longitude': -100.2575054,
#   'Route': 1},
#  {'dest_id': 1507,
#   'address': 'boulevard primavera 3530-6,Contry Tesoro,Monterrey,Nuevo León,México',
#   'latitude': 25.60248534,
#   'longitude': -100.2522533,
#   'Route': 1},
#  {'dest_id': 1552,
#   'address': 'BRECHA 306, LA ENRAMADA 1 SAN NICOLAS, SAN NICOLAS NL',
#   'latitude': 25.60353573,
#   'longitude': -100.263078,
#   'Route': 1},
#  {'dest_id': 1457,
#   'address': 'bosques del valle,Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.60098958,
#   'longitude': -100.2607331,
#   'Route': 1},
#  {'dest_id': 1654,
#   'address': 'Burdeos 5109, Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.6052686,
#   'longitude': -100.2528044,
#   'Route': 1},
#  {'dest_id': 1466,
#   'address': 'Bosques Mexicanos 122, Zona Bosques del Valle, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.601125,
#   'longitude': -100.2560784,
#   'Route': 1},
#  {'dest_id': 1348,
#   'address': 'Bosques de Los Pirineos 306, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.5974278,
#   'longitude': -100.2518059,
#   'Route': 1},
#  {'dest_id': 1549,
#   'address': 'Brazilia 210, Paraje Santa Rosa, 66607 Cd Apodaca, N.L., México, Ciudad Apodaca',
#   'latitude': 25.6034186,
#   'longitude': -100.2528682,
#   'Route': 1},
#  {'dest_id': 1633,
#   'address': 'Bulgary 507, Nexxus Esmeralda, 66055 Escobedo N.L.',
#   'latitude': 25.60501379,
#   'longitude': -100.2585949,
#   'Route': 1},
#  {'dest_id': 1396,
#   'address': 'Bosques de Puebla 326, Bosques del Valle 4to Sector, San Pedro Garza García, Nuevo Leon ',
#   'latitude': 25.59874151,
#   'longitude': -100.2627947,
#   'Route': 1},
#  {'dest_id': 1451,
#   'address': 'Bosques del Peñón 2271, Bosques de La Pastora 2o Sector, Guadalupe, N.L., México',
#   'latitude': 25.6008282,
#   'longitude': -100.2542006,
#   'Route': 1},
#  {'dest_id': 1453,
#   'address': 'Bosques del Tíbet 422, Bosques del Valle,66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.6008461,
#   'longitude': -100.2609375,
#   'Route': 1},
#  {'dest_id': 522,
#   'address': 'Ávila 390, Gonzalitos, 64020 Monterrey, N.L., México',
#   'latitude': 25.5696835,
#   'longitude': -100.2359141,
#   'Route': 2},
#  {'dest_id': 380,
#   'address': 'Avenida Paseo de los Leones 1388, Cumbres 1º Sector, Monterrey, Nuevo Leon',
#   'latitude': 25.563434,
#   'longitude': -100.232917,
#   'Route': 2},
#  {'dest_id': 377,
#   'address': 'Avenida Parte Aguas 100, Zona Loma Larga Poniente, San Pedro Garza García, N.L., México',
#   'latitude': 25.562954,
#   'longitude': -100.229109,
#   'Route': 2},
#  {'dest_id': 682,
#   'address': 'Balcones de cordova 136, balcones de las mitras 5 sector , monterrey',
#   'latitude': 25.5752714,
#   'longitude': -100.2278051,
#   'Route': 2},
#  {'dest_id': 484,
#   'address': 'Avenida Tamaulipas 540, Nuevo Apodaca, Apodaca, N.L.',
#   'latitude': 25.568155,
#   'longitude': -100.222821,
#   'Route': 2},
#  {'dest_id': 802,
#   'address': 'Belfort 220, Bosques de Las Cumbres, 64619 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.57695616,
#   'longitude': -100.2333283,
#   'Route': 2},
#  {'dest_id': 371,
#   'address': 'Avenida Pablo Livas 4211, La Roca, Guadalupe, N.L., México',
#   'latitude': 25.562713,
#   'longitude': -100.232568,
#   'Route': 2},
#  {'dest_id': 806,
#   'address': 'Bélgica 86 7004, México 86, Guadalupe, Nuevo Leon',
#   'latitude': 25.577002,
#   'longitude': -100.231032,
#   'Route': 2},
#  {'dest_id': 485,
#   'address': 'Avenida Teléfonos 211, Lomas del Pedregal, Apodaca, N.L.',
#   'latitude': 25.5682822,
#   'longitude': -100.2247681,
#   'Route': 2},
#  {'dest_id': 592,
#   'address': 'Bacio 106, Renacimiento, Colonia Miguel Hidalgo, 64925 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.572157,
#   'longitude': -100.2267613,
#   'Route': 2},
#  {'dest_id': 470,
#   'address': 'Avenida Santa Barbara 405, Casco Urbano, San Pedro Garza García, N.L.',
#   'latitude': 25.5675707,
#   'longitude': -100.2331811,
#   'Route': 2},
#  {'dest_id': 624,
#   'address': 'Bahía de Vizcaíno 4514, Las Brisas 4o. Sector, 64780 Monterrey, N.L., México',
#   'latitude': 25.5737249,
#   'longitude': -100.2285746,
#   'Route': 2},
#  {'dest_id': 681,
#   'address': 'Balcones de Andalucia, Sin Nombre de Col 6, Monterrey, N.L.',
#   'latitude': 25.57523251,
#   'longitude': -100.2280911,
#   'Route': 2},
#  {'dest_id': 613,
#   'address': 'BAHIA DE GUANTANAMO 3425 COLONIA RINCON DE LA PRIMAVERA  , MONTERREY ',
#   'latitude': 25.5731625,
#   'longitude': -100.2268782,
#   'Route': 2},
#  {'dest_id': 640,
#   'address': 'BAHIA LA PALMA 3469, RINCON DE LA PRIMAVERA, MONTERREY',
#   'latitude': 25.5740391,
#   'longitude': -100.2347795,
#   'Route': 2},
#  {'dest_id': 367,
#   'address': 'Avenida Pablo Livas 1026, Gustavo Díaz Ordaz, Guadalupe, N.L.',
#   'latitude': 25.5625005,
#   'longitude': -100.2322632,
#   'Route': 2},
#  {'dest_id': 820,
#   'address': 'Belisario Domínguez 2730, Jardín, 64050 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5772252,
#   'longitude': -100.2378278,
#   'Route': 2},
#  {'dest_id': 488,
#   'address': 'Avenida Tlachicuerias 621, Arboledas de Santo Domingo, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.56846978,
#   'longitude': -100.2320226,
#   'Route': 2},
#  {'dest_id': 396,
#   'address': 'Avenida Prados del Rey 427, Prados del Rey, Santa Catarina, Nuevo Leon',
#   'latitude': 25.5641997,
#   'longitude': -100.2330472,
#   'Route': 2},
#  {'dest_id': 538,
#   'address': 'Ayllon 1015, Monterrey, Nuevo Leon ',
#   'latitude': 25.5701459,
#   'longitude': -100.2302115,
#   'Route': 2},
#  {'dest_id': 408,
#   'address': 'Avenida Regio Parque 118, Ciudad Apodaca, Nuevo Leon',
#   'latitude': 25.5647966,
#   'longitude': -100.2361353,
#   'Route': 2},
#  {'dest_id': 378,
#   'address': 'Avenida Paseo de los Leones 105, 64100, Monterrey, Mexico',
#   'latitude': 25.56326,
#   'longitude': -100.232786,
#   'Route': 2},
#  {'dest_id': 725,
#   'address': 'Barcelona 108, Valles de Linda Vista, 67130 Guadalupe, N.L.',
#   'latitude': 25.576466,
#   'longitude': -100.2294423,
#   'Route': 2},
#  {'dest_id': 433,
#   'address': 'Avenida Roberto Garza Sada 109B, Bosques del Valle 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5661965,
#   'longitude': -100.2402381,
#   'Route': 2},
#  {'dest_id': 519,
#   'address': 'Aviana 532, Colonia, 66057 Cd Gral Escobedo, N.L., México, Ciudad General Escobedo',
#   'latitude': 25.56961861,
#   'longitude': -100.2427596,
#   'Route': 2},
#  {'dest_id': 617,
#   'address': 'Bahía de Panamá 3732, Rincon De La Primavera, 64835 Monterrey, N.L., México',
#   'latitude': 25.5735044,
#   'longitude': -100.2353488,
#   'Route': 2},
#  {'dest_id': 850,
#   'address': 'Benito Juárez 103, Barrio Tampiquito, Lomas de Tampiquito, 66240 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.57764266,
#   'longitude': -100.2339304,
#   'Route': 2},
#  {'dest_id': 861,
#   'address': 'Benito Juárez 303, Sin Nombre de Colonia 12, Ciudad Apodaca, N.L.',
#   'latitude': 25.57782169,
#   'longitude': -100.2378183,
#   'Route': 2},
#  {'dest_id': 435,
#   'address': 'Avenida Roberto Garza Sada 202, Lomas del Valle, Monterrey, N.L.',
#   'latitude': 25.56638715,
#   'longitude': -100.2300783,
#   'Route': 2},
#  {'dest_id': 363,
#   'address': 'Avenida Oriente 533, Villas de Casa Blanca 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.562227,
#   'longitude': -100.2439841,
#   'Route': 2},
#  {'dest_id': 576,
#   'address': 'Azurita 1019, Los Naranjos 1er Sector, 66448 San Nicolás de los Garza, N.L.',
#   'latitude': 25.571484,
#   'longitude': -100.235025,
#   'Route': 2},
#  {'dest_id': 356,
#   'address': 'Avenida Nexxus 104, Joyas de Anahuac, General Escobedo, Nuevo Leon',
#   'latitude': 25.561481,
#   'longitude': -100.2406123,
#   'Route': 2},
#  {'dest_id': 675,
#   'address': 'Balcones 300, Predio Residencial Satélite Regiomontano, Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5749784,
#   'longitude': -100.2328851,
#   'Route': 2},
#  {'dest_id': 508,
#   'address': 'Avenida Vista Real 543, Valle Oriente, 66266 San Pedro Garza García, N.L., México',
#   'latitude': 25.56948,
#   'longitude': -100.22598,
#   'Route': 2},
#  {'dest_id': 616,
#   'address': 'Bahía de Panamá 3728, Rincon De La Primavera, Monterrey, Nuevo Leon',
#   'latitude': 25.573369,
#   'longitude': -100.2372012,
#   'Route': 2},
#  {'dest_id': 647,
#   'address': 'Balcanes 32, Cordillera, Santa Catarina, Nuevo Leon',
#   'latitude': 25.5741171,
#   'longitude': -100.2373828,
#   'Route': 2},
#  {'dest_id': 500,
#   'address': 'avenida valle de san angel,Comercial Alpino Chipinque,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5691256,
#   'longitude': -100.2349871,
#   'Route': 2},
#  {'dest_id': 606,
#   'address': 'Bahía Blanca 3800, Rincon De La Primavera, Monterrey, N.L. ',
#   'latitude': 25.572607,
#   'longitude': -100.2381555,
#   'Route': 2},
#  {'dest_id': 625,
#   'address': 'Bahía del Geógrafo 3505, Rincon De La Primavera, Monterrey, Nuevo Leon',
#   'latitude': 25.57372491,
#   'longitude': -100.2285746,
#   'Route': 2},
#  {'dest_id': 727,
#   'address': 'Barcelona 122,Privadas de Anáhuac Sector Irlandes,General Escobedo,Nuevo León,México',
#   'latitude': 25.576504,
#   'longitude': -100.233351,
#   'Route': 2},
#  {'dest_id': 908,
#   'address': 'Bernardo Cobos Díaz 114, Alberta Escamilla, Apodaca, N.L.',
#   'latitude': 25.578606,
#   'longitude': -100.237048,
#   'Route': 2},
#  {'dest_id': 646,
#   'address': 'Balcanes 14, Cordillera, Santa Catarina, N.L.',
#   'latitude': 25.5741171,
#   'longitude': -100.2373828,
#   'Route': 2},
#  {'dest_id': 614,
#   'address': 'Bahía de guantánamo,Rincón de la Primavera,Monterrey,Nuevo León,México',
#   'latitude': 25.5731625,
#   'longitude': -100.2268782,
#   'Route': 2},
#  {'dest_id': 671,
#   'address': 'balcones 2603,balcones de altavista Monterrey n. l.',
#   'latitude': 25.5748483,
#   'longitude': -100.2321798,
#   'Route': 2},
#  {'dest_id': 425,
#   'address': 'Avenida Ricardo Margain Zozaya 271, Santa Engracia, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5659192,
#   'longitude': -100.2240794,
#   'Route': 2},
#  {'dest_id': 531,
#   'address': 'Aviñon 138\nFracc. Monticello\n66036 Garcia NL\nMéxico\n',
#   'latitude': 25.5699396,
#   'longitude': -100.2264167,
#   'Route': 2},
#  {'dest_id': 554,
#   'address': 'Azores 879, Sin Nombre de Colonia 26, Monterrey, N.L. Dpto 1',
#   'latitude': 25.570514,
#   'longitude': -100.230658,
#   'Route': 2},
#  {'dest_id': 909,
#   'address': 'Bernardo Cobos Díaz 148, Alberta Escamilla, Apodaca, N.L.',
#   'latitude': 25.5786147,
#   'longitude': -100.2358178,
#   'Route': 2},
#  {'dest_id': 386,
#   'address': 'Avenida Paseo de los Leones no. 648, Mitras Centro, Monterrey, N.L.',
#   'latitude': 25.5636488,
#   'longitude': -100.2261635,
#   'Route': 2},
#  {'dest_id': 591,
#   'address': 'Bacio 106, Renacimiento, Colonia Miguel Hidalgo, 64925 Monterrey, N.L., México',
#   'latitude': 25.572157,
#   'longitude': -100.2267613,
#   'Route': 2},
#  {'dest_id': 563,
#   'address': 'Azucena 443,Bosques del Poniente,Santa Catarina,Nuevo León,México',
#   'latitude': 25.5707706,
#   'longitude': -100.2339712,
#   'Route': 2},
#  {'dest_id': 629,
#   'address': 'bahía dorada 3724,Rincón de la Primavera,Monterrey,Nuevo León,México',
#   'latitude': 25.5737633,
#   'longitude': -100.2285313,
#   'Route': 2},
#  {'dest_id': 868,
#   'address': 'Benito Juárez 516, Cabecera Municipal (Apodaca), Apodaca Centro, Ciudad Apodaca, N.L.',
#   'latitude': 25.577861,
#   'longitude': -100.2325711,
#   'Route': 2},
#  {'dest_id': 453,
#   'address': 'Avenida San Jerónimo 810, San Jeronimo, Monterrey, N.L.',
#   'latitude': 25.5672186,
#   'longitude': -100.2369127,
#   'Route': 2},
#  {'dest_id': 578,
#   'address': 'Azurita 907A, Los Naranjos 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.57162043,
#   'longitude': -100.2374415,
#   'Route': 2},
#  {'dest_id': 669,
#   'address': 'BALCONES 1316 BALCONES DE COLINAS SAN JERONIMO MTY, N.L',
#   'latitude': 25.5748015,
#   'longitude': -100.235106,
#   'Route': 2},
#  {'dest_id': 668,
#   'address': 'balcones 118,Ciudad Satélite,Monterrey,Nuevo León,México',
#   'latitude': 25.57478808,
#   'longitude': -100.2380654,
#   'Route': 2},
#  {'dest_id': 374,
#   'address': 'Avenida Pablo Livas 7304, Residencial Santa María, Guadalupe, Nuevo Leon',
#   'latitude': 25.5627384,
#   'longitude': -100.230428,
#   'Route': 2},
#  {'dest_id': 438,
#   'address': 'Avenida Roberto Garza Sada 334, Bosques Del Valle, Bosques del Valle Ampliación 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5665079,
#   'longitude': -100.230039,
#   'Route': 2},
#  {'dest_id': 532,
#   'address': 'aviñon 312, dominio cumbres, fraccionamiento Montichello',
#   'latitude': 25.56993965,
#   'longitude': -100.2264167,
#   'Route': 2},
#  {'dest_id': 503,
#   'address': 'Avenida Vasconcelos 154, santa Engracia, San pedro garza garcia',
#   'latitude': 25.5692938,
#   'longitude': -100.2268625,
#   'Route': 2},
#  {'dest_id': 506,
#   'address': 'Avenida Vista Real 100, Zona Loma Larga Oriente, Monterrey, N.L.',
#   'latitude': 25.5694625,
#   'longitude': -100.2423652,
#   'Route': 2},
#  {'dest_id': 723,
#   'address': 'Barbados 113, Vista Hermosa, 64620 Monterrey, N.L., Mexico',
#   'latitude': 25.5764304,
#   'longitude': -100.2370641,
#   'Route': 2},
#  {'dest_id': 534,
#   'address': 'Avita Anáhuac, Los Banos 116, Sin Nombre de Colonia 20, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5700864,
#   'longitude': -100.2255924,
#   'Route': 2},
#  {'dest_id': 873,
#   'address': 'Benjamin Franklin 871, contra la silla, 67173, Guadalupe Nl',
#   'latitude': 25.57794584,
#   'longitude': -100.2340376,
#   'Route': 2},
#  {'dest_id': 810,
#   'address': 'Belice 430, Lomas del Pedregal, Apodaca, N.L.',
#   'latitude': 25.577022,
#   'longitude': -100.230352,
#   'Route': 2},
#  {'dest_id': 545,
#   'address': 'azafran 427,3 Caminos,Guadalupe,Nuevo León,México',
#   'latitude': 25.5704311,
#   'longitude': -100.2344764,
#   'Route': 2},
#  {'dest_id': 824,
#   'address': 'Belisario Domínguez 527, Floridos Bosques del Nogalar, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5772368,
#   'longitude': -100.230573,
#   'Route': 2},
#  {'dest_id': 601,
#   'address': 'Bahía Algeciras 3408, Rincon De La Primavera, 64835 Monterrey, N.L., México',
#   'latitude': 25.5724485,
#   'longitude': -100.2334436,
# ...
#   'latitude': 25.5785005,
#   'longitude': -100.255231,
#   'Route': 13},
#  {'dest_id': 949,
#   'address': 'Blas Chumacero 138, Alberta Escamilla, Apodaca, N.L.',
#   'latitude': 25.5797956,
#   'longitude': -100.2634517,
#   'Route': 13},
#  {'dest_id': 748,
#   'address': 'barisan 19, fracc cordillera, residencial valle poniente, santa catarina',
#   'latitude': 25.57665,
#   'longitude': -100.270209,
#   'Route': 13},
#  {'dest_id': 1037,
#   'address': 'BLVD. PUERTA DEL SOL 655,Colinas de San Jerónimo,Monterrey,Nuevo León,México',
#   'latitude': 25.5840825,
#   'longitude': -100.272884,
#   'Route': 13},
#  {'dest_id': 370,
#   'address': 'Avenida Pablo Livas 4211, Guadalupe Victoria, 67180 Guadalupe, N.L.',
#   'latitude': 25.5626772,
#   'longitude': -100.2567251,
#   'Route': 13},
#  {'dest_id': 903,
#   'address': 'Bernardino de Sahagún 110, Zona Tampiquito, Los Fresnos, 66244 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.5785005,
#   'longitude': -100.255231,
#   'Route': 13},
#  {'dest_id': 990,
#   'address': 'Blvd. Botánica 504, Valle del Campestre, 66266 San Pedro Garza García, N.L.',
#   'latitude': 25.5815355,
#   'longitude': -100.2661058,
#   'Route': 13},
#  {'dest_id': 333,
#   'address': 'Avenida Manuel L. Barragán 6512, Valle de Anáhuac, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5597,
#   'longitude': -100.254831,
#   'Route': 13},
#  {'dest_id': 896,
#   'address': 'Bernabé González 6716, Topo Chico, 64260 Monterrey, N.L.',
#   'latitude': 25.578337,
#   'longitude': -100.267864,
#   'Route': 13},
#  {'dest_id': 986,
#   'address': 'Blvd. Botánica 407, Valle del Campestre, 66266 San Pedro Garza García, N.L.',
#   'latitude': 25.5814352,
#   'longitude': -100.2592337,
#   'Route': 13},
#  {'dest_id': 865,
#   'address': 'Benito Juárez 321, Sta Catarina, 66350 Santa Catarina, N.L., México, Santa Catarina',
#   'latitude': 25.577844,
#   'longitude': -100.268337,
#   'Route': 13},
#  {'dest_id': 800,
#   'address': 'Belfort 111, Bosques de Las Cumbres, 64619 Monterrey, N.L., México',
#   'latitude': 25.5769389,
#   'longitude': -100.2665194,
#   'Route': 13},
#  {'dest_id': 945,
#   'address': 'Blanca Vista 220, Linda Vista, 67130 Guadalupe, N.L.',
#   'latitude': 25.579773,
#   'longitude': -100.2600787,
#   'Route': 13},
#  {'dest_id': 853,
#   'address': 'Benito Juárez 111, Barrio Tampiquito, Lomas de Tampiquito, 66240 San Pedro Garza García, N.L., Mexico, San Pedro Garza García',
#   'latitude': 25.5776816,
#   'longitude': -100.2561104,
#   'Route': 13},
#  {'dest_id': 967,
#   'address': 'Blvd. Acapulco 800, Josefa Zozaya, 67110 Guadalupe, N.L., México, Guadalupe',
#   'latitude': 25.5804505,
#   'longitude': -100.2632253,
#   'Route': 13},
#  {'dest_id': 989,
#   'address': 'Blvd. Botánica 504 C1101, Valle del Campestre, 66266 San Pedro Garza García, N.L., México',
#   'latitude': 25.5815161,
#   'longitude': -100.2591522,
#   'Route': 13},
#  {'dest_id': 892,
#   'address': 'Berna 909, El Refugio 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.57826308,
#   'longitude': -100.2619436,
#   'Route': 13},
#  {'dest_id': 845,
#   'address': 'Benito J. Feijoo 101, Zona Tampiquito, Los Fresnos, 66240 San Pedro Garza García, N.L., México',
#   'latitude': 25.5775376,
#   'longitude': -100.2694489,
#   'Route': 13},
#  {'dest_id': 843,
#   'address': 'Benito J. Feijoo 101, Barrio Tampiquito, Capistrano, 66240 San Pedro Garza García, N.L., México',
#   'latitude': 25.577494,
#   'longitude': -100.269582,
#   'Route': 13},
#  {'dest_id': 912,
#   'address': 'Berrendo 103, San Patricio 4o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5786676,
#   'longitude': -100.2634545,
#   'Route': 13},
#  {'dest_id': 993,
#   'address': 'Blvd. Botánica 504, Valle del Campestre, 66266 San Pedro Garza García, N.L., Mexico, San Pedro Garza García',
#   'latitude': 25.5816562,
#   'longitude': -100.2592837,
#   'Route': 13},
#  {'dest_id': 724,
#   'address': 'Barbados 1253, Residencial Santa Fe, 67117 Guadalupe, N.L.',
#   'latitude': 25.5764509,
#   'longitude': -100.259681,
#   'Route': 13},
#  {'dest_id': 883,
#   'address': 'Berlin 593b, Paseo de las Flores, Apodaca, Nuevo Leon',
#   'latitude': 25.57811,
#   'longitude': -100.263431,
#   'Route': 13},
#  {'dest_id': 877,
#   'address': 'bereda de las aves 155,La Estancia,San Nicolás de los Garza,Nuevo León,México',
#   'latitude': 25.5779841,
#   'longitude': -100.2711359,
#   'Route': 13},
#  {'dest_id': 1008,
#   'address': 'Blvd. Díaz Ordaz 26, San Jeronimo, Monterrey, Nuevo Leon',
#   'latitude': 25.5824397,
#   'longitude': -100.2608914,
#   'Route': 13},
#  {'dest_id': 1100,
#   'address': 'Borbón 125, Dinastía, Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5866073,
#   'longitude': -100.2640641,
#   'Route': 13},
#  {'dest_id': 696,
#   'address': 'Balcones del Valle, 64790 Monterrey, N.L.',
#   'latitude': 25.5756443,
#   'longitude': -100.2601406,
#   'Route': 13},
#  {'dest_id': 902,
#   'address': 'Bernardino de Sahagún 104,Capistrano,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.57850031,
#   'longitude': -100.2552309,
#   'Route': 13},
#  {'dest_id': 893,
#   'address': 'Bernabé de Las Casas 536, Misión de Fundadores, Ciudad Apodaca, Nuevo Leon',
#   'latitude': 25.5782631,
#   'longitude': -100.2619436,
#   'Route': 13},
#  {'dest_id': 698,
#   'address': 'Balcones Núm. 1 1303, Colinas de San Jerónimo 10o. Sector, Monterrey, N.L., México',
#   'latitude': 25.5757344,
#   'longitude': -100.2593007,
#   'Route': 13},
#  {'dest_id': 726,
#   'address': 'Barcelona 121, Rincón de San Jerónimo, 64635 Monterrey, N.L.',
#   'latitude': 25.576485,
#   'longitude': -100.2629979,
#   'Route': 13},
#  {'dest_id': 952,
#   'address': 'blvd',
#   'latitude': 25.57988024,
#   'longitude': -100.2592941,
#   'Route': 13},
#  {'dest_id': 977,
#   'address': 'Blvd. Antonio L. Rodríguez 2000, Santa María, 64650 Monterrey, N.L., Mexico',
#   'latitude': 25.58091223,
#   'longitude': -100.2585858,
#   'Route': 13},
#  {'dest_id': 1047,
#   'address': 'Blvd. Puerta del Sol 766, Colinas de San Jerónimo 4o. Sector, Monterrey, N.L.',
#   'latitude': 25.5843065,
#   'longitude': -100.2680747,
#   'Route': 13},
#  {'dest_id': 871,
#   'address': 'Benito Pérez Galdós 614, Jardín Español, Monterrey, Nuevo Leon',
#   'latitude': 25.57789625,
#   'longitude': -100.2622286,
#   'Route': 13},
#  {'dest_id': 807,
#   'address': 'Belgrado, Sector Irlandés Sur, Privadas de Anáhuac Sector Irlandes, Cd Gral Escobedo, N.L., Mexico',
#   'latitude': 25.57700576,
#   'longitude': -100.2704427,
#   'Route': 13},
#  {'dest_id': 346,
#   'address': 'Avenida Miguel Alemán 5391, Privada Purísima, Guadalupe, Nuevo Leon',
#   'latitude': 25.5608546,
#   'longitude': -100.2530025,
#   'Route': 13},
#  {'dest_id': 951,
#   'address': 'blvd',
#   'latitude': 25.57987995,
#   'longitude': -100.2609772,
#   'Route': 13},
#  {'dest_id': 694,
#   'address': 'Balcones del Popocatepetl, Sin Nombre de Col 6, Monterrey, N.L., México',
#   'latitude': 25.575563,
#   'longitude': -100.2594116,
#   'Route': 13},
#  {'dest_id': 983,
#   'address': 'Blvd. Apodaca 902A Technology Park, Apodaca, 66600 Cd Apodaca, N.L.',
#   'latitude': 25.5809833,
#   'longitude': -100.2620791,
#   'Route': 13},
#  {'dest_id': 891,
#   'address': 'Bermudas 147, Vista Hermosa, Monterrey, Nuevo Leon',
#   'latitude': 25.57826292,
#   'longitude': -100.2619434,
#   'Route': 13},
#  {'dest_id': 697,
#   'address': 'Balcones del valle, calle joreg r garza casa 11, san pedro garza garcia NL',
#   'latitude': 25.57572168,
#   'longitude': -100.2638766,
#   'Route': 13},
#  {'dest_id': 685,
#   'address': 'Balcones de la Colina 5316, Monterrey, 64790, Balcones del Mirador',
#   'latitude': 25.575292,
#   'longitude': -100.259068,
#   'Route': 13},
#  {'dest_id': 846,
#   'address': 'Benito Juarez  2211, 15 de Mayo (Larralde), 64450, Monterrey',
#   'latitude': 25.5775376,
#   'longitude': -100.2694489,
#   'Route': 13},
#  {'dest_id': 365,
#   'address': 'Avenida Oscar Arizpe 414, Constituyentes de Queretaro 2do Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.562376,
#   'longitude': -100.2541394,
#   'Route': 13},
#  {'dest_id': 917,
#   'address': 'BERTHA WESTRUP 316, VILLA LUZ, APODACA',
#   'latitude': 25.578794,
#   'longitude': -100.26927,
#   'Route': 13},
#  {'dest_id': 755,
#   'address': 'Barranca 208, Veredalta, 66270 San Pedro Garza García, N.L.',
#   'latitude': 25.57669911,
#   'longitude': -100.2703341,
#   'Route': 13},
#  {'dest_id': 1038,
#   'address': 'Blvd. Puerta del Sol 668, Colinas de San Jerónimo, 64640 Monterrey, N.L.',
#   'latitude': 25.5841188,
#   'longitude': -100.2729168,
#   'Route': 13},
#  {'dest_id': 935,
#   'address': 'Bioma Residencial, Camino Al Diente 198, Bioma Residencial, Monterrey, Nuevo Leon',
#   'latitude': 25.579286,
#   'longitude': -100.2668273,
#   'Route': 13},
#  {'dest_id': 978,
#   'address': 'Blvd. Antonio L. Rodríguez 2100 Edificio BH Piso 11 Int 116, Privada Sta. María, 64650 Monterrey, N.L., Mexico',
#   'latitude': 25.5809169,
#   'longitude': -100.2623021,
#   'Route': 13},
#  {'dest_id': 966,
#   'address': 'Blvd. Acapulco 800, Josefa Zozaya, 67110 Guadalupe, N.L., México',
#   'latitude': 25.58042972,
#   'longitude': -100.2632896,
#   'Route': 13},
#  {'dest_id': 467,
#   'address': 'Avenida Santa Barbara 264, Zona Los Callejones, Monterrey, Nuevo León',
#   'latitude': 25.5675248,
#   'longitude': -100.2570827,
#   'Route': 13},
#  {'dest_id': 1003,
#   'address': 'Blvd. Díaz Ordaz 16, Sin Nombre de Col 27, Monterrey, N.L., México',
#   'latitude': 25.5823768,
#   'longitude': -100.2608362,
#   'Route': 13},
#  {'dest_id': 1129,
#   'address': 'Bosque Andaluz 516, Las Lomas Sector Bosques, N.L., México',
#   'latitude': 25.5870958,
#   'longitude': -100.2607587,
#   'Route': 13},
#  {'dest_id': 933,
#   'address': 'Bilbao 914, Valles de Linda Vista, Guadalupe, Nuevo León',
#   'latitude': 25.57916,
#   'longitude': -100.271464,
#   'Route': 13},
#  {'dest_id': 771,
#   'address': 'Basalto 4812, Villa Dorada, Monterrey, Nuevo Leon',
#   'latitude': 25.5767444,
#   'longitude': -100.2647559,
#   'Route': 13},
#  {'dest_id': 335,
#   'address': 'Avenida Manuel Ordoñez 335, Centro, Santa Catarina, N.L.',
#   'latitude': 25.5597002,
#   'longitude': -100.2548306,
#   'Route': 13},
#  {'dest_id': 924,
#   'address': 'Biar 107,Ancestra,San Nicolás de los Garza,Nuevo León,México',
#   'latitude': 25.57901912,
#   'longitude': -100.261675,
#   'Route': 13},
#  {'dest_id': 797,
#   'address': 'Belen 407, Sin Nombre de Colonia 51, Monterrey, N.L.',
#   'latitude': 25.5768879,
#   'longitude': -100.2653258,
#   'Route': 13},
#  {'dest_id': 848,
#   'address': 'Benito Juárez 100-2, Santa Catarina, 66350 Santa Catarina, N.L.',
#   'latitude': 25.5775682,
#   'longitude': -100.2588513,
#   'Route': 13},
#  {'dest_id': 942,
#   'address': 'Bizancio 616-620, Jardines de San Agustín 2o Sector, 66274 San Pedro Garza García, N.L.',
#   'latitude': 25.579591,
#   'longitude': -100.260429,
#   'Route': 13},
#  {'dest_id': 336,
#   'address': 'Avenida Manuel Ordoñez 700, Bosques del Poniente, Santa Catarina, Nuevo Leon',
#   'latitude': 25.5597002,
#   'longitude': -100.2548306,
#   'Route': 13},
#  {'dest_id': 717,
#   'address': 'baraka 16, almena II, santa catarina, monterrey',
#   'latitude': 25.5762811,
#   'longitude': -100.2625685,
#   'Route': 13},
#  {'dest_id': 940,
#   'address': 'Bizancio 602, Jardines de San Agustín 2o Sector, San Pedro Garza García, N.L. , ,',
#   'latitude': 25.57941468,
#   'longitude': -100.2600553,
#   'Route': 13},
#  {'dest_id': 821,
#   'address': 'Belisario Domínguez 507, Vista Montaña 3ER Sector, 66214 San Pedro Garza García, N.L.',
#   'latitude': 25.5772293,
#   'longitude': -100.2642914,
#   'Route': 13},
#  {'dest_id': 1041,
#   'address': 'Blvd. Puerta del Sol 702, Colinas de San Jerónimo 1o. Sector, Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5841844,
#   'longitude': -100.2679452,
#   'Route': 13},
#  {'dest_id': 1057,
#   'address': 'Blvrd Aeropuerto 171, Nuevo León',
#   'latitude': 25.5849687,
#   'longitude': -100.2692787,
#   'Route': 13},
#  {'dest_id': 919,
#   'address': 'Bet-el 711, Betel, 66430 San Nicolás de los Garza, N.L., México, San Nicolás de los Garza',
#   'latitude': 25.5787956,
#   'longitude': -100.2694944,
#   'Route': 13},
#  {'dest_id': 364,
#   'address': 'Avenida Oscar Arizpe 308, Constituyentes de Queretaro 2do Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5622437,
#   'longitude': -100.2572703,
#   'Route': 13},
#  {'dest_id': 965,
#   'address': 'Blvd. Acapulco 424, La Fe, 66477 San Nicolás de los Garza, N.L.',
#   'latitude': 25.5803848,
#   'longitude': -100.2596411,
#   'Route': 13},
#  {'dest_id': 1031,
#   'address': 'Blvd. Puerta del Sol 539, Colinas de San Jerónimo 1o. Sector, Monterrey, N.L., México',
#   'latitude': 25.58366838,
#   'longitude': -100.2719308,
#   'Route': 13},
#  {'dest_id': 982,
#   'address': 'blvd. Antonio l. Rodríguez,San Jerónimo,Monterrey,Nuevo León,México',
#   'latitude': 25.5809832,
#   'longitude': -100.262079,
#   'Route': 13},
#  {'dest_id': 863,
#   'address': 'Benito Juárez 307, Sin Nombre de Colonia 12, Ciudad Apodaca, N.L.',
#   'latitude': 25.5778356,
#   'longitude': -100.2547427,
#   'Route': 13},
#  {'dest_id': 816,
#   'address': 'Belisario Domínguez 2470, Centro, 64000 Monterrey, N.L., México',
#   'latitude': 25.5771928,
#   'longitude': -100.2703536,
#   'Route': 13},
#  {'dest_id': 707,
#   'address': 'Bambú 1603, Sin Nombre de Col 50, Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5760376,
#   'longitude': -100.2662318,
#   'Route': 13},
#  {'dest_id': 1001,
#   'address': 'Blvd. Díaz Ordaz 120, Santa María, 64650 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5822667,
#   'longitude': -100.2607091,
#   'Route': 13},
#  {'dest_id': 972,
#   'address': 'Blvd. Antonio L. Rodríguez 1888, Santa María, Monterrey, N.L.',
#   'latitude': 25.5806416,
#   'longitude': -100.2650013,
#   'Route': 13},
#  {'dest_id': 918,
#   'address': 'Bertha Westrup 424, Villa Luz, Apodaca, N.L.',
#   'latitude': 25.578794,
#   'longitude': -100.26927,
#   'Route': 13},
#  {'dest_id': 878,
#   'address': 'Berel 505, Ladrillera, 64830 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5780077,
#   'longitude': -100.2652671,
#   'Route': 13},
#  {'dest_id': 934,
#   'address': 'Bilbao Ote 308, Entre Monte Everest y Av. Puerta de Hierro, Fracc. Crisanto Residencial, la entrada a la colonia est√° sobre Av. Cumbres Madeira',
#   'latitude': 25.57922158,
#   'longitude': -100.2612219,
#   'Route': 13},
#  {'dest_id': 953,
#   'address': 'BLVD FORJADORES 1202 253, FRACC ARBORETO , SN PEDRO CHOLULA ',
#   'latitude': 25.5799226,
#   'longitude': -100.2641045,
#   'Route': 13},
#  {'dest_id': 955,
#   'address': 'Blvd Gustavo Díaz Ordaz 159, La Fama, 66100 Santa Catarina, Nuevo Leon',
#   'latitude': 25.5799335,
#   'longitude': -100.2678849,
#   'Route': 13},
#  {'dest_id': 730,
#   'address': 'Barcelona 125, Satélite Acuerducto, Monterrey',
#   'latitude': 25.57659519,
#   'longitude': -100.4145273,
#   'Route': 14},
#  {'dest_id': 19,
#   'address': 'Avenida Cristóbal Colón 171, Sarabia, Monterrey, Nuevo Leon ',
#   'latitude': 25.36281586,
#   'longitude': -100.1019522,
#   'Route': 15},
#  {'dest_id': 26,
#   'address': 'Avenida Cristóbal Colón 171, Sarabia, Monterrey, Nuevo Leon ',
#   'latitude': 25.3643172,
#   'longitude': -100.1031895,
#   'Route': 15},
#  {'dest_id': 30,
#   'address': 'Avenida Cuauhtémoc 105, Residencial Cuauhtémoc, Santa Catarina, N.L. LAS PALMAS',
#   'latitude': 25.3714975,
#   'longitude': -100.1067322,
#   'Route': 15},
#  {'dest_id': 25,
#   'address': 'Avenida Cristóbal Colón 171, Sarabia, Monterrey, Nuevo Leon ',
#   'latitude': 25.3643131,
#   'longitude': -100.1031873,
#   'Route': 15},
#  {'dest_id': 33,
#   'address': 'AVENIDA DE LA CIMA 156 COLONIA CUMBRES 3ER SECTOR ,MONTERREY',
#   'latitude': 25.3864862,
#   'longitude': -100.1144393,
#   'Route': 15},
#  {'dest_id': 32,
#   'address': 'Avenida Damasco 408, Tréboles, Ciudad Apodaca, N.L.',
#   'latitude': 25.3860321,
#   'longitude': -100.1120283,
#   'Route': 15},
#  {'dest_id': 24,
#   'address': 'Avenida Cristóbal Colón 171, Sarabia, Monterrey, Nuevo Leon ',
#   'latitude': 25.364313,
#   'longitude': -100.103187,
#   'Route': 15},
#  {'dest_id': 28,
#   'address': 'Avenida Cristóbal Colón 171, Sarabia, Monterrey, Nuevo Leon ',
#   'latitude': 25.3707985,
#   'longitude': -100.1038893,
#   'Route': 15},
#  {'dest_id': 31,
#   'address': 'Avenida Cuauhtémoc 455, Del Norte, Monterrey, Nuevo Leon',
#   'latitude': 25.3716849,
#   'longitude': -100.1044297,
#   'Route': 15}]

# %%
# Plot the predicted clusters to see if the model predicted the correct clusters
# This is visual validation that the model was trained correctly.
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
