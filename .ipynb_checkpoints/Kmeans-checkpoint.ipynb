# %%
# %pip install numpy
# %pip install matplotlib
# %pip install yellowbrick
# %pip install sklearn
# %pip install sqlalchemy
# %pip install pandas
# %pip install psycopg2
# %pip install flask
import math
import psycopg2
import numpy as np
import matplotlib.pyplot as plt
import yellowbrick 
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_score 
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from flask import jsonify
import pandas as pd
import random

# %%
# Database info
database_url = 'postgres://wnjhouloendxny:b027f83c1f0723e6c2c0f515d8bcdcd126d8dbd84cfa0ce97a0826379797f553@ec2-54-152-40-168.compute-1.amazonaws.com:5432/d8207vdcs70hmd'
    
# Database Connection
engine = create_engine(database_url)

# reflect an existing database into a new model
Base = automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
Destinations = Base.classes.destinations

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

destinations_data = session.query(Destinations.dest_id, Destinations.address, 
                    Destinations.latitude, Destinations.longitude).all()

# Close session
session.close()

# Convert query results to a dictionary
dest_ls = []
for dest_id, address, latitude, longitude in destinations_data:
    dest_dict = {}
    dest_dict["dest_id"] = dest_id
    dest_dict["address"] = address
    dest_dict["latitude"] = latitude
    dest_dict["longitude"] = longitude
    dest_ls.append(dest_dict)

# Convert list to dataframe
destinations_df = pd.DataFrame(dest_ls)

# Sample for project purpose
seed = 42
sample = destinations_df.sample(n=1715, axis=0, random_state = seed)
sample
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-c26b14d50526> in <module>
#      23 # Sample for project purpose
#      24 seed = 42
# ---> 25 sample = destinations_df.sample(n=1716, axis=0, random_state = seed)
#      26 sample
#
# ~/opt/anaconda3/envs/PythonAdv/lib/python3.6/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5059             )
#    5060
# -> 5061         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5062         return self.take(locs, axis=axis)
#    5063
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
LatLon = []
LatLonLists = []
y_nones = []
lat = list(sample['latitude'])
lon = list(sample['longitude'])


for i in range(len(sample)):
    LatLon.append(lat[i])
    LatLon.append(lon[i])
    LatLonLists.append(LatLon)
    y_nones.append(None)
    LatLon = []
    
X=np.array(LatLonLists)
y=np.array(y_nones)
#print(LatLonLists)
print(X, y)
# Out:
# [[  25.569804   -100.244204  ]
#  [  25.6034186  -100.2528682 ]
#  [  25.60501379 -100.2585949 ]
#  ...
#  [  25.54778893 -100.2305944 ]
#  [  25.594408   -100.2556203 ]
#  [  25.5939204  -100.2473967 ]] [None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None]

# %%
y = y.reshape(len(y),1)
print(y.shape, X.shape)
#print(y)
# Out:
# (1000, 1) (1000, 2)

# %%
cargomax = 200
vehicles = 40
minK = math.ceil(max(len(sample)/cargomax,2))
maxK = min(vehicles,len(sample))
Ks = range(minK, maxK)
km = [KMeans(n_clusters=i, random_state = seed) for i in Ks]
score = [silhouette_score(X,km[i].fit(X).predict(X),random_state=seed) for i in range(len(km))]
maxscore = np.argmax(score)
index = min(np.argmax(score) + minK,vehicles)
Ks, score, maxscore, index
# Out:
# (range(5, 40),
#  [0.49767250873750457,
#   0.5058331367849026,
#   0.5056276579981349,
#   0.48490631457365074,
#   0.48278798767467956,
#   0.4605758186492699,
#   0.46278973426132186,
#   0.4664043894158363,
#   0.46485297790769037,
#   0.4667962556214434,
#   0.46614362114107305,
#   0.4719593683815266,
#   0.4643470122057322,
#   0.4567239506485321,
#   0.4609354374885823,
#   0.4399989033287624,
#   0.4672452079810345,
#   0.4724176115815371,
#   0.4633318769616784,
#   0.4698343305245356,
#   0.46956836885198294,
#   0.46473191114449036,
#   0.46272921396745653,
#   0.46196076823911564,
#   0.46061339395638073,
#   0.46850090447694615,
#   0.45933634772735504,
#   0.4594476832485575,
#   0.4576926292973193,
#   0.4589114959210222,
#   0.45223323073870797,
#   0.4538016371225768,
#   0.45493099910598206,
#   0.4754458367331927,
#   0.46638729792126804],
#  1,
#  6)

# %%
# Use n_clusters=4 as the k value
# We can see from the plot above that there are 4 clusters
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=index, random_state = seed)

# %%
# Fit the model to the data
kmeans.fit(X)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %% [markdown]
# Predict the clusters
# predicted_clusters = kmeans.predict(X)
# predicted_clusters

# %%
predicted_clusters = kmeans.predict(X)

# %%
sample['Route'] = predicted_clusters
sample.sort_values(by=['Route'],axis=0,ascending=True,inplace=True)
sample.to_csv()
output_list = sample.to_dict("records")
output_list
# Out:
# [{'dest_id': 525,
#   'address': 'Avilés 403, Nueva Galicia, 64160 Monterrey, N.L., México',
#   'latitude': 25.569804,
#   'longitude': -100.244204,
#   'Route': 0},
#  {'dest_id': 597,
#   'address': 'Bahamas 239, Vista Hermosa, 64620 Monterrey, N.L., México',
#   'latitude': 25.5723197,
#   'longitude': -100.2340452,
#   'Route': 0},
#  {'dest_id': 850,
#   'address': 'Benito Juárez 103, Barrio Tampiquito, Lomas de Tampiquito, 66240 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.57764266,
#   'longitude': -100.2339304,
#   'Route': 0},
#  {'dest_id': 767,
#   'address': 'Barranquilla 221, Paraje Santa Rosa, Nuevo Leon',
#   'latitude': 25.57673699,
#   'longitude': -100.2487034,
#   'Route': 0},
#  {'dest_id': 563,
#   'address': 'Azucena 443,Bosques del Poniente,Santa Catarina,Nuevo León,México',
#   'latitude': 25.5707706,
#   'longitude': -100.2339712,
#   'Route': 0},
#  {'dest_id': 873,
#   'address': 'Benjamin Franklin 871, contra la silla, 67173, Guadalupe Nl',
#   'latitude': 25.57794584,
#   'longitude': -100.2340376,
#   'Route': 0},
#  {'dest_id': 791,
#   'address': 'Begonia 1013, Jardines de Escobedo III, General Escobedo, N.L. , ,',
#   'latitude': 25.5768698,
#   'longitude': -100.2486251,
#   'Route': 0},
#  {'dest_id': 814,
#   'address': 'Belisario Domínguez 2120, Obispado, Monterrey, N.L., México',
#   'latitude': 25.5771007,
#   'longitude': -100.2428107,
#   'Route': 0},
#  {'dest_id': 929,
#   'address': 'Bilbao 4025, Las Torres, Monterrey, N.L.',
#   'latitude': 25.5790991,
#   'longitude': -100.243512,
#   'Route': 0},
#  {'dest_id': 230,
#   'address': 'Avenida José Vasconcelos 501C, Del Valle, 66220 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.541542,
#   'longitude': -100.233329,
#   'Route': 0},
#  {'dest_id': 532,
#   'address': 'aviñon 312, dominio cumbres, fraccionamiento Montichello',
#   'latitude': 25.56993965,
#   'longitude': -100.2264167,
#   'Route': 0},
#  {'dest_id': 812,
#   'address': 'Belisario Domínguez 1914, Centro, 64000 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.577037,
#   'longitude': -100.2342703,
#   'Route': 0},
#  {'dest_id': 928,
#   'address': 'Bilbao 244, Valles de Linda Vista, 67130 Guadalupe, N.L.',
#   'latitude': 25.5790991,
#   'longitude': -100.243512,
#   'Route': 0},
#  {'dest_id': 671,
#   'address': 'balcones 2603,balcones de altavista Monterrey n. l.',
#   'latitude': 25.5748483,
#   'longitude': -100.2321798,
#   'Route': 0},
#  {'dest_id': 396,
#   'address': 'Avenida Prados del Rey 427, Prados del Rey, Santa Catarina, Nuevo Leon',
#   'latitude': 25.5641997,
#   'longitude': -100.2330472,
#   'Route': 0},
#  {'dest_id': 646,
#   'address': 'Balcanes 14, Cordillera, Santa Catarina, N.L.',
#   'latitude': 25.5741171,
#   'longitude': -100.2373828,
#   'Route': 0},
#  {'dest_id': 727,
#   'address': 'Barcelona 122,Privadas de Anáhuac Sector Irlandes,General Escobedo,Nuevo León,México',
#   'latitude': 25.576504,
#   'longitude': -100.233351,
#   'Route': 0},
#  {'dest_id': 278,
#   'address': 'Avenida Lázaro Cárdenas 1010, Residencial San Agustín 1er Sector, San Pedro Garza García, Nuevo León',
#   'latitude': 25.5520953,
#   'longitude': -100.2334799,
#   'Route': 0},
#  {'dest_id': 354,
#   'address': 'Avenida Morones Prieto 2110, Real del Valle 1 Sector, Monterrey, Nuevo León',
#   'latitude': 25.5611939,
#   'longitude': -100.2269098,
#   'Route': 0},
#  {'dest_id': 500,
#   'address': 'avenida valle de san angel,Comercial Alpino Chipinque,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5691256,
#   'longitude': -100.2349871,
#   'Route': 0},
#  {'dest_id': 554,
#   'address': 'Azores 879, Sin Nombre de Colonia 26, Monterrey, N.L. Dpto 1',
#   'latitude': 25.570514,
#   'longitude': -100.230658,
#   'Route': 0},
#  {'dest_id': 517,
#   'address': 'Avestruces 317, San Jerónimo 4o. Sector, 64634 Monterrey, N.L., Mexico',
#   'latitude': 25.5696113,
#   'longitude': -100.2440674,
#   'Route': 0},
#  {'dest_id': 859,
#   'address': 'Benito Juárez 2613, Lomas de Tolteca, 67170 Guadalupe, N.L.',
#   'latitude': 25.5778061,
#   'longitude': -100.2422041,
#   'Route': 0},
#  {'dest_id': 908,
#   'address': 'Bernardo Cobos Díaz 114, Alberta Escamilla, Apodaca, N.L.',
#   'latitude': 25.578606,
#   'longitude': -100.237048,
#   'Route': 0},
#  {'dest_id': 348,
#   'address': 'Avenida Miradores 60000c, Lomas de Satélite, Monterrey, Nuevo León',
#   'latitude': 25.56103793,
#   'longitude': -100.2316333,
#   'Route': 0},
#  {'dest_id': 530,
#   'address': 'Aviñon 138\nFracc. Monticello\n66036 Garcia NL\nMéxico\n',
#   'latitude': 25.5699396,
#   'longitude': -100.2264167,
#   'Route': 0},
#  {'dest_id': 229,
#   'address': 'Avenida José Vasconcelos 455, Del Valle, 66240 San Pedro Garza García, N.L., México',
#   'latitude': 25.541391,
#   'longitude': -100.23788,
#   'Route': 0},
#  {'dest_id': 744,
#   'address': 'bari 721, Altaria Residencial, Calle Carr A Huinala, Lomas del Pedregal, Cd Apodaca, N.L., México',
#   'latitude': 25.57663599,
#   'longitude': -100.2485435,
#   'Route': 0},
#  {'dest_id': 806,
#   'address': 'Bélgica 86 7004, México 86, Guadalupe, Nuevo Leon',
#   'latitude': 25.577002,
#   'longitude': -100.231032,
#   'Route': 0},
#  {'dest_id': 290,
#   'address': 'Avenida Lázaro Cárdenas 4336, Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.5556055,
#   'longitude': -100.2235663,
#   'Route': 0},
#  {'dest_id': 624,
#   'address': 'Bahía de Vizcaíno 4514, Las Brisas 4o. Sector, 64780 Monterrey, N.L., México',
#   'latitude': 25.5737249,
#   'longitude': -100.2285746,
#   'Route': 0},
#  {'dest_id': 725,
#   'address': 'Barcelona 108, Valles de Linda Vista, 67130 Guadalupe, N.L.',
#   'latitude': 25.576466,
#   'longitude': -100.2294423,
#   'Route': 0},
#  {'dest_id': 994,
#   'address': 'Blvd. Botánica 507, Valle del Campestre, 66265 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.58170727,
#   'longitude': -100.235094,
#   'Route': 0},
#  {'dest_id': 584,
#   'address': 'B. de Bolonia 421, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.57182443,
#   'longitude': -100.2343846,
#   'Route': 0},
#  {'dest_id': 593,
#   'address': 'Bacum 347, Las Sabinas, 67169 Guadalupe, N.L., México',
#   'latitude': 25.572157,
#   'longitude': -100.226761,
#   'Route': 0},
#  {'dest_id': 1132,
#   'address': 'Bosque Catalán, Las Lomas Sector Jardines, N.L., México',
#   'latitude': 25.587152,
#   'longitude': -100.242716,
#   'Route': 0},
#  {'dest_id': 439,
#   'address': 'Avenida Roberto Garza Sada 401, Carrizalejo, San Pedro Garza García, N.L., México',
#   'latitude': 25.5665079,
#   'longitude': -100.230039,
#   'Route': 0},
#  {'dest_id': 823,
#   'address': 'Belisario Domínguez 527, Floridos Bosques del Nogalar, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5772368,
#   'longitude': -100.2305725,
#   'Route': 0},
#  {'dest_id': 313,
#   'address': 'Avenida Manuel Gómez Morín 100, Carrizalejo, San Pedro Garza García, Nuevo León',
#   'latitude': 25.5578321,
#   'longitude': -100.2274561,
#   'Route': 0},
#  {'dest_id': 310,
#   'address': 'Avenida Luis Elizondo 306, Tecnológico, 64700 Monterrey, N.L.',
#   'latitude': 25.55742784,
#   'longitude': -100.2252434,
#   'Route': 0},
#  {'dest_id': 318,
#   'address': 'Avenida Manuel Gómez Morín 2005, Residencial Chipinque 1er Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.558319,
#   'longitude': -100.225011,
#   'Route': 0},
#  {'dest_id': 445,
#   'address': 'Avenida Rómulo Garza 917, Constituyentes de Queretaro 4to Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.566876,
#   'longitude': -100.234633,
#   'Route': 0},
#  {'dest_id': 970,
#   'address': 'Blvd. Antonio L. Rodríguez 1888, Real del Valle 1 Sector, Monterrey, Nuevo León',
#   'latitude': 25.580622,
#   'longitude': -100.244022,
#   'Route': 0},
#  {'dest_id': 323,
#   'address': 'Avenida Manuel Gómez Morín 2005, Residencial Chipinque 1er Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.558778,
#   'longitude': -100.226463,
#   'Route': 0},
#  {'dest_id': 270,
#   'address': 'Avenida Las Plazas 67100, Nuevo León, México',
#   'latitude': 25.550605,
#   'longitude': -100.220153,
#   'Route': 0},
#  {'dest_id': 604,
#   'address': 'Bahía Blanca 3742, Rincon De La Primavera, 64835 Monterrey, N.L., México',
#   'latitude': 25.57260696,
#   'longitude': -100.2381553,
#   'Route': 0},
#  {'dest_id': 529,
#   'address': 'AVINON  105, CERRADAS DE CONCORDIA, APODACA',
#   'latitude': 25.5699331,
#   'longitude': -100.2274722,
#   'Route': 0},
#  {'dest_id': 285,
#   'address': 'Avenida Lázaro Cárdenas 2424, Residencial San Agustín 1er Sector, 66269 San Pedro Garza García, N.L.',
#   'latitude': 25.5546543,
#   'longitude': -100.2244335,
#   'Route': 0},
#  {'dest_id': 234,
#   'address': 'Avenida José Vasconcelos 618, Casco Urbano, 66230 San Pedro Garza García, N.L.',
#   'latitude': 25.542698,
#   'longitude': -100.221048,
#   'Route': 0},
#  {'dest_id': 379,
#   'address': 'Avenida Paseo de los Leones 105, 64100, Monterrey, Mexico',
#   'latitude': 25.563422,
#   'longitude': -100.227087,
#   'Route': 0},
#  {'dest_id': 944,
#   'address': 'Blanca 345, Los Candiles, 66647 Cd Apodaca, N.L., México',
#   'latitude': 25.5797056,
#   'longitude': -100.2438026,
#   'Route': 0},
#  {'dest_id': 453,
#   'address': 'Avenida San Jerónimo 810, San Jeronimo, Monterrey, N.L.',
#   'latitude': 25.5672186,
#   'longitude': -100.2369127,
#   'Route': 0},
#  {'dest_id': 269,
#   'address': 'Avenida las Palmas 436, Valle del Salduero, Nuevo Leon',
#   'latitude': 25.550025,
#   'longitude': -100.2322993,
#   'Route': 0},
#  {'dest_id': 1117,
#   'address': 'Borrely 317, Espacio Cumbres, 64349 Monterrey N.L.',
#   'latitude': 25.5868277,
#   'longitude': -100.2388545,
#   'Route': 0},
#  {'dest_id': 641,
#   'address': 'Baja California 417, Independencia, Monterrey, N.L., México',
#   'latitude': 25.5740391,
#   'longitude': -100.2347795,
#   'Route': 0},
#  {'dest_id': 721,
#   'address': 'Barbados 1125, Residencial Santa Fe, Guadalupe, Nuevo Leon',
#   'latitude': 25.576424,
#   'longitude': -100.24436,
#   'Route': 0},
#  {'dest_id': 627,
#   'address': 'bahía dorada  3741, Rincón de la Primavera, Bahía Dorada, Rincon De La Primavera, 64835 Monterrey, N.L., México',
#   'latitude': 25.57375227,
#   'longitude': -100.2440269,
#   'Route': 0},
#  {'dest_id': 546,
#   'address': 'Azalea 5510, Valle Verde, 64117 Monterrey, N.L., México',
#   'latitude': 25.5704311,
#   'longitude': -100.2344764,
#   'Route': 0},
#  {'dest_id': 811,
#   'address': 'Belisario Domínguez 1718, Centro, 64000 Monterrey, N.L., México',
#   'latitude': 25.57703691,
#   'longitude': -100.2342701,
#   'Route': 0},
#  {'dest_id': 260,
#   'address': 'Avenida la Rioja 131, Monterrey, N.L.',
#   'latitude': 25.548901,
#   'longitude': -100.21588,
#   'Route': 0},
#  {'dest_id': 302,
#   'address': 'Avenida Lomas del Vergel 133, Monterrey, N.L.',
#   'latitude': 25.5563385,
#   'longitude': -100.2262319,
#   'Route': 0},
#  {'dest_id': 340,
#   'address': 'Avenida Miguel Alemán 399, INFONAVIT la Huasteca, Santa Catarina, Nuevo Leon',
#   'latitude': 25.5605079,
#   'longitude': -100.2243998,
#   'Route': 0},
#  {'dest_id': 240,
#   'address': 'Avenida José Vasconcelos 745, Col. del Valle, San Pedro Garza García, N.L., México',
#   'latitude': 25.54314903,
#   'longitude': -100.2203083,
#   'Route': 0},
#  {'dest_id': 248,
#   'address': 'Avenida José Vasconcelos 811, Zona Santa Barbara Poniente, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.54682186,
#   'longitude': -100.2305847,
#   'Route': 0},
#  {'dest_id': 357,
#   'address': 'Avenida No Reelección 4969, Mitra Dorada, Monterrey, Nuevo Leon',
#   'latitude': 25.5616175,
#   'longitude': -100.2202111,
#   'Route': 0},
#  {'dest_id': 241,
#   'address': 'Avenida José Vasconcelos 745, Los Sabinos, 66226 San Pedro Garza García, N.L.,',
#   'latitude': 25.54314903,
#   'longitude': -100.2203083,
#   'Route': 0},
#  {'dest_id': 255,
#   'address': 'avenida la herradura 105, la herradura',
#   'latitude': 25.5479718,
#   'longitude': -100.2256037,
#   'Route': 0},
#  {'dest_id': 498,
#   'address': 'Avenida Universidad SN-S, Anáhuac, 66450 San Nicolás de los Garza, N.L., México, San Nicolás de los Garza',
#   'latitude': 25.5690465,
#   'longitude': -100.2335545,
#   'Route': 0},
#  {'dest_id': 890,
#   'address': 'BERMUDAS 1211, RESIDENCIAL SANTA FE, FUADALUPE',
#   'latitude': 25.5782568,
#   'longitude': -100.2367349,
#   'Route': 0},
#  {'dest_id': 560,
#   'address': 'Azucena 232, Prados del Nogalar, San Nicolás de los Garza, N.L.',
#   'latitude': 25.5707342,
#   'longitude': -100.229763,
#   'Route': 0},
#  {'dest_id': 760,
#   'address': 'Barranco 5005, Rincón del Valle, 64660 Monterrey, N.L., México',
#   'latitude': 25.57671553,
#   'longitude': -100.2485703,
#   'Route': 0},
#  {'dest_id': 243,
#   'address': 'Avenida José Vasconcelos 755, Los Sabinos, 66226 San Pedro Garza García, N.L., México',
#   'latitude': 25.54505071,
#   'longitude': -100.2146008,
#   'Route': 0},
#  {'dest_id': 842,
#   'address': 'Bengali 115, Cuauhtémoc, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.57746997,
#   'longitude': -100.2332824,
#   'Route': 0},
#  {'dest_id': 602,
#   'address': 'Bahía Algeciras 3408, Rincon De La Primavera, 64835 Monterrey, N.L., México',
#   'latitude': 25.5724961,
#   'longitude': -100.2433394,
#   'Route': 0},
#  {'dest_id': 1004,
#   'address': 'Blvd. Díaz Ordaz 26, San Jeronimo, 64660 Monterrey, N.L.',
#   'latitude': 25.58240657,
#   'longitude': -100.2463621,
#   'Route': 0},
#  {'dest_id': 353,
#   'address': 'Avenida Morenita Mia 359, San Bartolo, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5611838,
#   'longitude': -100.2315914,
#   'Route': 0},
#  {'dest_id': 528,
#   'address': 'aviñon',
#   'latitude': 25.56986857,
#   'longitude': -100.2265099,
#   'Route': 0},
#  {'dest_id': 789,
#   'address': 'Beethoven 1000, Misión de Anáhuac, 66059 Cd Gral Escobedo, N.L.',
#   'latitude': 25.5768698,
#   'longitude': -100.2486251,
#   'Route': 0},
#  {'dest_id': 254,
#   'address': 'avenida la herradura 105 , la herradura',
#   'latitude': 25.5477891,
#   'longitude': -100.2305947,
#   'Route': 0},
#  {'dest_id': 386,
#   'address': 'Avenida Paseo de los Leones no. 648, Mitras Centro, Monterrey, N.L.',
#   'latitude': 25.5636488,
#   'longitude': -100.2261635,
#   'Route': 0},
#  {'dest_id': 969,
#   'address': 'Blvd. Antonio L. Rodríguez 1882, Sin Nombre de Col 27, 64650 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5805678,
#   'longitude': -100.2484462,
#   'Route': 0},
#  {'dest_id': 836,
#   'address': 'belloc,Valle de Cumbres,García,Nuevo León,México',
#   'latitude': 25.57735396,
#   'longitude': -100.2458137,
#   'Route': 0},
#  {'dest_id': 508,
#   'address': 'Avenida Vista Real 543, Valle Oriente, 66266 San Pedro Garza García, N.L., México',
#   'latitude': 25.56948,
#   'longitude': -100.22598,
#   'Route': 0},
#  {'dest_id': 592,
#   'address': 'Bacio 106, Renacimiento, Colonia Miguel Hidalgo, 64925 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.572157,
#   'longitude': -100.2267613,
#   'Route': 0},
#  {'dest_id': 703,
#   'address': 'Balzac 906,Misión de Anáhuac,General Escobedo,Nuevo León,México',
#   'latitude': 25.575886,
#   'longitude': -100.24194,
#   'Route': 0},
#  {'dest_id': 484,
#   'address': 'Avenida Tamaulipas 540, Nuevo Apodaca, Apodaca, N.L.',
#   'latitude': 25.568155,
#   'longitude': -100.222821,
#   'Route': 0},
#  {'dest_id': 277,
#   'address': 'Avenida Lázaro Cárdenas 1010, Residencial San Agustín 1er Sector, San Pedro Garza García, Nuevo León',
#   'latitude': 25.5518551,
#   'longitude': -100.2191963,
#   'Route': 0},
#  {'dest_id': 941,
#   'address': 'Bizancio 614, Jardines de San Agustín 2o Sector, 66274 San Pedro Garza García, N.L.',
#   'latitude': 25.5795356,
#   'longitude': -100.2492447,
#   'Route': 0},
#  {'dest_id': 366,
#   'address': 'Avenida Oscar Arizpe 426, Constituyentes de Queretaro 2do Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5624648,
#   'longitude': -100.2292457,
#   'Route': 0},
#  {'dest_id': 371,
#   'address': 'Avenida Pablo Livas 4211, La Roca, Guadalupe, N.L., México',
#   'latitude': 25.562713,
#   'longitude': -100.232568,
#   'Route': 0},
#  {'dest_id': 343,
#   'address': 'Avenida Miguel Aleman 405, La huasteca, Santa Catarina',
#   'latitude': 25.5605874,
#   'longitude': -100.2314134,
#   'Route': 0},
#  {'dest_id': 485,
#   'address': 'Avenida Teléfonos 211, Lomas del Pedregal, Apodaca, N.L.',
#   'latitude': 25.5682822,
#   'longitude': -100.2247681,
#   'Route': 0},
#  {'dest_id': 625,
#   'address': 'Bahía del Geógrafo 3505, Rincon De La Primavera, Monterrey, Nuevo Leon',
#   'latitude': 25.57372491,
#   'longitude': -100.2285746,
#   'Route': 0},
#  {'dest_id': 315,
#   'address': 'Avenida Manuel Gómez Morín 126, Zona Residencial Chipinque, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.55819,
#   'longitude': -100.227181,
#   'Route': 0},
#  {'dest_id': 640,
#   'address': 'BAHIA LA PALMA 3469, RINCON DE LA PRIMAVERA, MONTERREY',
#   'latitude': 25.5740391,
#   'longitude': -100.2347795,
#   'Route': 0},
#  {'dest_id': 435,
#   'address': 'Avenida Roberto Garza Sada 202, Lomas del Valle, Monterrey, N.L.',
#   'latitude': 25.56638715,
#   'longitude': -100.2300783,
#   'Route': 0},
#  {'dest_id': 820,
#   'address': 'Belisario Domínguez 2730, Jardín, 64050 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5772252,
#   'longitude': -100.2378278,
#   'Route': 0},
#  {'dest_id': 668,
#   'address': 'balcones 118,Ciudad Satélite,Monterrey,Nuevo León,México',
#   'latitude': 25.57478808,
#   'longitude': -100.2380654,
#   'Route': 0},
#  {'dest_id': 293,
#   'address': 'Avenida Lázaro Cárdenas 4336, Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.5557852,
#   'longitude': -100.225106,
#   'Route': 0},
#  {'dest_id': 368,
#   'address': 'Avenida Pablo Livas 2204, La Quinta, 67170 Guadalupe, N.L., Mexico',
#   'latitude': 25.5626439,
#   'longitude': -100.2281694,
#   'Route': 0},
#  {'dest_id': 1128,
#   'address': 'Bosque Amazónico 194, León, Gto., México',
#   'latitude': 25.58709,
#   'longitude': -100.242799,
#   'Route': 0},
#  {'dest_id': 516,
#   'address': 'Avenue Paseo de San Luis 114, Misión de Guadalupe, Guadalupe, N.L.',
#   'latitude': 25.5696113,
#   'longitude': -100.2440674,
#   'Route': 0},
#  {'dest_id': 365,
#   'address': 'Avenida Oscar Arizpe 414, Constituyentes de Queretaro 2do Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.562376,
#   'longitude': -100.2541394,
#   'Route': 0},
#  {'dest_id': 578,
#   'address': 'Azurita 907A, Los Naranjos 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.57162043,
#   'longitude': -100.2374415,
#   'Route': 0},
#  {'dest_id': 833,
#   'address': 'Bellini 827, Contry La Silla 8o Sector, 67173 Guadalupe, N.L., México',
#   'latitude': 25.5772951,
#   'longitude': -100.2416522,
#   'Route': 0},
#  {'dest_id': 909,
#   'address': 'Bernardo Cobos Díaz 148, Alberta Escamilla, Apodaca, N.L.',
#   'latitude': 25.5786147,
#   'longitude': -100.2358178,
#   'Route': 0},
#  {'dest_id': 316,
#   'address': 'Avenida Manuel Gómez Morín 132-5, Comercial Gómez Morin, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.55829411,
#   'longitude': -100.2246466,
#   'Route': 0},
#  {'dest_id': 393,
#   'address': 'Avenida Portal del Huajuco 313, Portal del Huajuco, Monterrey, N.L., México',
#   'latitude': 25.564012,
#   'longitude': -100.230166,
#   'Route': 0},
#  {'dest_id': 247,
#   'address': 'Avenida José Vasconcelos 811, Zona Santa Barbara Poniente, San Pedro Garza García, N.L.',
#   'latitude': 25.5465621,
#   'longitude': -100.233154,
#   'Route': 0},
#  {'dest_id': 581,
#   'address': 'Azurita 947B, Los Naranjos 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.571711,
#   'longitude': -100.234328,
#   'Route': 0},
#  {'dest_id': 616,
#   'address': 'Bahía de Panamá 3728, Rincon De La Primavera, Monterrey, Nuevo Leon',
#   'latitude': 25.573369,
#   'longitude': -100.2372012,
#   'Route': 0},
#  {'dest_id': 350,
#   'address': 'Avenida miradores exterior. 6000B int. 17, satelite seccion miradores, monterrey nl',
#   'latitude': 25.56118356,
#   'longitude': -100.2315912,
#   'Route': 0},
#  {'dest_id': 531,
#   'address': 'Aviñon 138\nFracc. Monticello\n66036 Garcia NL\nMéxico\n',
#   'latitude': 25.5699396,
#   'longitude': -100.2264167,
#   'Route': 0},
#  {'dest_id': 723,
#   'address': 'Barbados 113, Vista Hermosa, 64620 Monterrey, N.L., Mexico',
#   'latitude': 25.5764304,
#   'longitude': -100.2370641,
#   'Route': 0},
#  {'dest_id': 786,
#   'address': 'Bavaria 2816, Rincón de Alta Vista, 64844 Monterrey, N.L., México',
#   'latitude': 25.5768698,
#   'longitude': -100.2486251,
#   'Route': 0},
#  {'dest_id': 503,
#   'address': 'Avenida Vasconcelos 154, santa Engracia, San pedro garza garcia',
#   'latitude': 25.5692938,
#   'longitude': -100.2268625,
#   'Route': 0},
#  {'dest_id': 438,
#   'address': 'Avenida Roberto Garza Sada 334, Bosques Del Valle, Bosques del Valle Ampliación 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5665079,
#   'longitude': -100.230039,
#   'Route': 0},
#  {'dest_id': 824,
#   'address': 'Belisario Domínguez 527, Floridos Bosques del Nogalar, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5772368,
#   'longitude': -100.230573,
#   'Route': 0},
#  {'dest_id': 345,
#   'address': 'Avenida Miguel Alemán 405, Mirador de la Huasteca, Sin Nombre de Colonia 22, Santa Catarina, Nuevo Leon',
#   'latitude': 25.56071958,
#   'longitude': -100.2244136,
#   'Route': 0},
#  {'dest_id': 330,
#   'address': 'Avenida Manuel Gómez Morín 500, Valle de Santa Engracia, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.559529,
#   'longitude': -100.233459,
#   'Route': 0},
#  {'dest_id': 617,
#   'address': 'Bahía de Panamá 3732, Rincon De La Primavera, 64835 Monterrey, N.L., México',
#   'latitude': 25.5735044,
#   'longitude': -100.2353488,
#   'Route': 0},
#  {'dest_id': 713,
#   'address': 'Baptist Restaurante Social, Calzada del Valle, Del Valle, Monterrey, Nuevo Leon',
#   'latitude': 25.57617712,
#   'longitude': -100.2484459,
#   'Route': 0},
#  {'dest_id': 570,
#   'address': 'Azucenas 510, Industrias del Vidrio Oriente, San Nicolás de los Garza, Nuevo León',
#   'latitude': 25.5711568,
#   'longitude': -100.2375555,
#   'Route': 0},
#  {'dest_id': 431,
#   'address': 'Avenida Roberto Garza Sada 101, Carrizalejo, San Pedro Garza García, N.L.',
#   'latitude': 25.566114,
#   'longitude': -100.240495,
#   'Route': 0},
#  {'dest_id': 298,
#   'address': 'Avenida Lince 107, Cumbres Elite 7o. Sector, Monterrey, Nuevo Leon',
#   'latitude': 25.55605946,
#   'longitude': -100.2264216,
#   'Route': 0},
#  {'dest_id': 289,
#   'address': 'Avenida Lázaro Cárdenas 301, Valle del Mirador, Monterrey, Nuevo Leon',
#   'latitude': 25.5553563,
#   'longitude': -100.2323261,
#   'Route': 0},
#  {'dest_id': 704,
#   'address': 'Balzac 917, Misión de Anáhuac, 66059 Cd Gral Escobedo, N.L.',
#   'latitude': 25.5758889,
#   'longitude': -100.2361586,
#   'Route': 0},
#  {'dest_id': 757,
#   'address': 'Barranca 217, Veredalta, San Pedro Garza García, Nuevo León',
#   'latitude': 25.576708,
#   'longitude': -100.2346793,
#   'Route': 0},
#  {'dest_id': 364,
#   'address': 'Avenida Oscar Arizpe 308, Constituyentes de Queretaro 2do Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5622437,
#   'longitude': -100.2572703,
#   'Route': 0},
#  {'dest_id': 450,
#   'address': 'avenida San Agustín,Residencial San Agustín Segundo Sector,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.567124,
#   'longitude': -100.2460113,
#   'Route': 0},
#  {'dest_id': 312,
#   'address': 'Avenida Magueyes 117, Praderas de Santo Domingo, San Nicolás de los Garza, N.L.',
#   'latitude': 25.5577754,
#   'longitude': -100.2290369,
#   'Route': 0},
#  {'dest_id': 433,
#   'address': 'Avenida Roberto Garza Sada 109B, Bosques del Valle 5o Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5661965,
#   'longitude': -100.2402381,
#   'Route': 0},
#  {'dest_id': 682,
#   'address': 'Balcones de cordova 136, balcones de las mitras 5 sector , monterrey',
#   'latitude': 25.5752714,
#   'longitude': -100.2278051,
#   'Route': 0},
#  {'dest_id': 813,
#   'address': 'Belisario Domínguez 2020, Centro, 64000 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5770558,
#   'longitude': -100.2418441,
#   'Route': 0},
#  {'dest_id': 327,
#   'address': 'Avenida Manuel Gómez Morín 404, 66266, San Pedro Garza García, Mexico',
#   'latitude': 25.5592212,
#   'longitude': -100.220712,
#   'Route': 0},
#  {'dest_id': 861,
#   'address': 'Benito Juárez 303, Sin Nombre de Colonia 12, Ciudad Apodaca, N.L.',
#   'latitude': 25.57782169,
#   'longitude': -100.2378183,
#   'Route': 0},
#  {'dest_id': 715,
#   'address': 'baptisterio 110,Valle de San Ángel Sect Jardines,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5761804,
#   'longitude': -100.2424917,
#   'Route': 0},
#  {'dest_id': 629,
#   'address': 'bahía dorada 3724,Rincón de la Primavera,Monterrey,Nuevo León,México',
#   'latitude': 25.5737633,
#   'longitude': -100.2285313,
#   'Route': 0},
#  {'dest_id': 295,
#   'address': 'Avenida Lázaro Cárdenas 436, Valle Oriente, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5559055,
#   'longitude': -100.2263255,
#   'Route': 0},
#  {'dest_id': 286,
#   'address': 'Avenida Lázaro Cárdenas 2424, Zona Loma Larga Oriente, Monterrey, Nuevo Leon',
#   'latitude': 25.5546922,
#   'longitude': -100.2245823,
#   'Route': 0},
#  {'dest_id': 939,
#   'address': 'Bizancio 319, Jardines de San Agustín 1er Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.5793982,
#   'longitude': -100.2439662,
#   'Route': 0},
#  {'dest_id': 747,
#   'address': 'Barisan 15m, Cordillera, Santa Catarina, Nuevo Leon',
#   'latitude': 25.5766499,
#   'longitude': -100.2484821,
#   'Route': 0},
#  {'dest_id': 519,
#   'address': 'Aviana 532, Colonia, 66057 Cd Gral Escobedo, N.L., México, Ciudad General Escobedo',
#   'latitude': 25.56961861,
#   'longitude': -100.2427596,
#   'Route': 0},
#  {'dest_id': 359,
#   'address': 'Avenida Olmeca 119-6, La Fuente, Guadalupe, Nuevo Leon',
#   'latitude': 25.5617606,
#   'longitude': -100.2285171,
#   'Route': 0},
#  {'dest_id': 758,
#   'address': 'Barranca 300,Veredalta,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.576708,
#   'longitude': -100.2346793,
#   'Route': 0},
#  {'dest_id': 718,
#   'address': 'Baraka, Santa Catarina, N.L., Mexico',
#   'latitude': 25.57628639,
#   'longitude': -100.2485025,
#   'Route': 0},
#  {'dest_id': 901,
#   'address': 'Bernardino de Sahagún 104,Capistrano,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5784378,
#   'longitude': -100.2437805,
#   'Route': 0},
#  {'dest_id': 380,
#   'address': 'Avenida Paseo de los Leones 1388, Cumbres 1º Sector, Monterrey, Nuevo Leon',
#   'latitude': 25.563434,
#   'longitude': -100.232917,
#   'Route': 0},
#  {'dest_id': 906,
#   'address': 'bernardo',
#   'latitude': 25.5785222,
#   'longitude': -100.2435821,
#   'Route': 0},
#  {'dest_id': 1124,
#   'address': 'Bosque 123, Arboledas de Corregidora, 67130 Monterrey, N.L., México',
#   'latitude': 25.5869887,
#   'longitude': -100.2429369,
#   'Route': 0},
#  {'dest_id': 300,
#   'address': 'Avenida Lince 168 Cumbres Elite, Monterrey',
#   'latitude': 25.5561456,
#   'longitude': -100.2315177,
#   'Route': 0},
#  {'dest_id': 1105,
#   'address': 'Borbon 207, Privada Montejo, Alberto García Guzmán, Privada Montejo, Santa Catarina, Nuevo Leon ',
#   'latitude': 25.58664383,
#   'longitude': -100.2427009,
#   'Route': 0},
#  {'dest_id': 840,
#   'address': 'Bengalí #169,Los Faisanes,Guadalupe,Nuevo León,México',
#   'latitude': 25.5774399,
#   'longitude': -100.2333295,
#   'Route': 0},
#  {'dest_id': 838,
#   'address': 'bendello 1626,Villas de Canterías,Monterrey,Nuevo León,México',
#   'latitude': 25.5773707,
#   'longitude': -100.2357713,
#   'Route': 0},
#  {'dest_id': 373,
#   'address': 'Avenida Pablo Livas 7304, Residencial Santa María, Guadalupe, Nuevo Leon',
#   'latitude': 25.5627384,
#   'longitude': -100.230428,
#   'Route': 0},
#  {'dest_id': 224,
#   'address': 'Avenida José Vasconcelos 355, Zona Campestre, 66267 San Pedro Garza García, N.L.',
#   'latitude': 25.5392011,
#   'longitude': -100.236582,
#   'Route': 0},
#  {'dest_id': 436,
#   'address': 'Avenida Roberto Garza Sada 202, Lomas del Valle, Monterrey, N.L.',
#   'latitude': 25.566417,
#   'longitude': -100.225424,
#   'Route': 0},
#  {'dest_id': 759,
#   'address': 'Barranca de Oblatos 220, Las Sierras, 66377 Santa Catarina, N.L.',
#   'latitude': 25.576708,
#   'longitude': -100.2346793,
#   'Route': 0},
#  {'dest_id': 869,
#   'address': 'Benito Juárez 539, Martínez Domínguez, 66356 Santa Catarina, N.L., México, Santa Catarina',
#   'latitude': 25.5778717,
#   'longitude': -100.2430917,
#   'Route': 0},
#  {'dest_id': 762,
#   'address': 'Barranquilla 126, Alta Vista, 64840 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.57673004,
#   'longitude': -100.2486927,
#   'Route': 0},
#  {'dest_id': 367,
#   'address': 'Avenida Pablo Livas 1026, Gustavo Díaz Ordaz, Guadalupe, N.L.',
#   'latitude': 25.5625005,
#   'longitude': -100.2322632,
#   'Route': 0},
#  {'dest_id': 329,
#   'address': 'Avenida Manuel Gómez Morín 420, Del Valle, 66290 San Pedro Garza García, N.L.',
#   'latitude': 25.559366,
#   'longitude': -100.22816,
#   'Route': 0},
#  {'dest_id': 591,
#   'address': 'Bacio 106, Renacimiento, Colonia Miguel Hidalgo, 64925 Monterrey, N.L., México',
#   'latitude': 25.572157,
#   'longitude': -100.2267613,
#   'Route': 0},
#  {'dest_id': 303,
#   'address': 'Avenida Lomas del Vergel 222, Monterrey, Nuevo Leon',
#   'latitude': 25.5564148,
#   'longitude': -100.2262903,
#   'Route': 0},
#  {'dest_id': 926,
#   'address': 'BILBAO 206 COLONIA PASEO DEL VERGEL ,MONTERREY ',
#   'latitude': 25.579099,
#   'longitude': -100.243512,
#   'Route': 0},
#  {'dest_id': 1092,
#   'address': 'Bora 126, Cumbres Provenza, N.L.',
#   'latitude': 25.58649249,
#   'longitude': -100.2411152,
#   'Route': 0},
#  {'dest_id': 576,
#   'address': 'Azurita 1019, Los Naranjos 1er Sector, 66448 San Nicolás de los Garza, N.L.',
#   'latitude': 25.571484,
#   'longitude': -100.235025,
#   'Route': 0},
#  {'dest_id': 239,
#   'address': 'Avenida José Vasconcelos 725_4, Del Valle, 66220 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.54314903,
#   'longitude': -100.2203083,
#   'Route': 0},
#  {'dest_id': 506,
#   'address': 'Avenida Vista Real 100, Zona Loma Larga Oriente, Monterrey, N.L.',
#   'latitude': 25.5694625,
#   'longitude': -100.2423652,
#   'Route': 0},
#  {'dest_id': 358,
#   'address': 'Avenida No Reelección 6223, Misión Lincoln, Monterrey, Nuevo León',
#   'latitude': 25.5617477,
#   'longitude': -100.2272948,
#   'Route': 0},
#  {'dest_id': 362,
#   'address': 'Avenida Oriente 533, Villas de Casa Blanca 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.56207551,
#   'longitude': -100.2282884,
#   'Route': 0},
#  {'dest_id': 281,
#   'address': 'Avenida Lázaro Cárdenas 1601, Jardín de Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.55255,
#   'longitude': -100.219663,
#   'Route': 0},
#  {'dest_id': 1061,
#   'address': 'Blvrd San Francisco 855, Cabecera Municipal (Apodaca), Residencial San Francisco, 66600 Cd Apodaca, N.L., México, Ciudad Apodaca',
#   'latitude': 25.5857371,
#   'longitude': -100.2416186,
#   'Route': 0},
#  {'dest_id': 470,
#   'address': 'Avenida Santa Barbara 405, Casco Urbano, San Pedro Garza García, N.L.',
#   'latitude': 25.5675707,
#   'longitude': -100.2331811,
#   'Route': 0},
#  {'dest_id': 325,
#   'address': 'Avenida Manuel Gómez Morín 2111, Residencial Chipinque 1er Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.55904695,
#   'longitude': -100.2264471,
#   'Route': 0},
#  {'dest_id': 225,
#   'address': 'Avenida José Vasconcelos 402, Valle de Santa Engracia, San Pedro Garza García, N.L.',
#   'latitude': 25.539435,
#   'longitude': -100.234673,
#   'Route': 0},
#  {'dest_id': 980,
#   'address': 'Blvd. Antonio L. Rodríguez 3062\nSanta María, Monterrey',
#   'latitude': 25.5809808,
#   'longitude': -100.2464638,
#   'Route': 0},
#  {'dest_id': 545,
#   'address': 'azafran 427,3 Caminos,Guadalupe,Nuevo León,México',
#   'latitude': 25.5704311,
#   'longitude': -100.2344764,
#   'Route': 0},
#  {'dest_id': 246,
#   'address': 'Avenida José Vasconcelos 811, Los Sabinos, San Pedro Garza García, Nuevo León',
#   'latitude': 25.5465621,
#   'longitude': -100.2331535,
#   'Route': 0},
#  {'dest_id': 614,
#   'address': 'Bahía de guantánamo,Rincón de la Primavera,Monterrey,Nuevo León,México',
#   'latitude': 25.5731625,
#   'longitude': -100.2268782,
#   'Route': 0},
#  {'dest_id': 810,
#   'address': 'Belice 430, Lomas del Pedregal, Apodaca, N.L.',
#   'latitude': 25.577022,
#   'longitude': -100.230352,
#   'Route': 0},
#  {'dest_id': 998,
#   'address': 'Blvd. de Las Cascadas, Lomas de Angelópolis, Pue., México',
#   'latitude': 25.5821075,
#   'longitude': -100.2447664,
#   'Route': 0},
#  {'dest_id': 534,
#   'address': 'Avita Anáhuac, Los Banos 116, Sin Nombre de Colonia 20, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5700864,
#   'longitude': -100.2255924,
#   'Route': 0},
#  {'dest_id': 681,
#   'address': 'Balcones de Andalucia, Sin Nombre de Col 6, Monterrey, N.L.',
#   'latitude': 25.57523251,
#   'longitude': -100.2280911,
#   'Route': 0},
#  {'dest_id': 296,
#   'address': 'Avenida Lázaro Cárdenas 436, Valle Oriente, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5559555,
#   'longitude': -100.2361059,
#   'Route': 0},
#  {'dest_id': 331,
#   'address': 'Avenida Manuel Gómez Morín 955, Zona Santa Barbara, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5595858,
#   'longitude': -100.2315509,
#   'Route': 0},
#  {'dest_id': 352,
#   'address': 'Avenida Morenita Mia 351, San Bartolo, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.56118372,
#   'longitude': -100.2315914,
#   'Route': 0},
#  {'dest_id': 574,
#   'address': 'Azul, Sin Nombre de Colonia 51, Monterrey, Nuevo León, México',
#   'latitude': 25.5713248,
#   'longitude': -100.2269341,
#   'Route': 0},
#  {'dest_id': 1071,
#   'address': 'Bocaccio 134, Colinas de San Jerónimo 4o. Sector, Monterrey, N.L.',
#   'latitude': 25.58600093,
#   'longitude': -100.243923,
#   'Route': 0},
#  {'dest_id': 1720,
#   'address': 'C. Torre del Campo 231, Valle Torremolinos, 67117 Guadalupe, N.L., México',
#   'latitude': 25.6061887,
#   'longitude': -100.1709108,
#   'Route': 0},
#  {'dest_id': 778,
#   'address': 'batallon de San Patricio 112,Valle de San Agustin,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5768365,
#   'longitude': -100.2324233,
#   'Route': 0},
#  {'dest_id': 291,
#   'address': 'Avenida Lázaro Cárdenas 4336, Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.55578511,
#   'longitude': -100.225106,
#   'Route': 0},
#  {'dest_id': 461,
#   'address': 'Avenida Santa Barbara 242, Zona Los Callejones, Monterrey, Nuevo Leon ',
#   'latitude': 25.56739399,
#   'longitude': -100.2369038,
#   'Route': 0},
#  {'dest_id': 378,
#   'address': 'Avenida Paseo de los Leones 105, 64100, Monterrey, Mexico',
#   'latitude': 25.56326,
#   'longitude': -100.232786,
#   'Route': 0},
#  {'dest_id': 493,
#   'address': 'Avenida Universidad 303, Roble 2do Sector, 66450 Monterrey, N.L., México',
#   'latitude': 25.5687122,
#   'longitude': -100.2347946,
#   'Route': 0},
#  {'dest_id': 337,
#   'address': 'Avenida Manuela Herrera 637, Colonai Villa Sol, Apodaca, N.L.',
#   'latitude': 25.559801,
#   'longitude': -100.2270082,
#   'Route': 0},
#  {'dest_id': 454,
#   'address': 'Avenida San José 2853, San Jorge, Monterrey, N.L.',
#   'latitude': 25.5672193,
#   'longitude': -100.2360893,
#   'Route': 0},
#  {'dest_id': 314,
#   'address': 'Avenida Manuel Gómez Morín 126, Zona Residencial Chipinque, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5580531,
#   'longitude': -100.2265311,
#   'Route': 0},
#  {'dest_id': 332,
#   'address': 'Avenida Manuel Gómez Morín 955, Zona Santa Barbara, San Pedro Garza García, Nuevo León',
#   'latitude': 25.5596134,
#   'longitude': -100.2333095,
#   'Route': 0},
#  {'dest_id': 849,
#   'address': 'Benito Juárez 100-2, Santa Catarina, Nuevo Leon',
#   'latitude': 25.57757522,
#   'longitude': -100.2335489,
#   'Route': 0},
#  {'dest_id': 802,
#   'address': 'Belfort 220, Bosques de Las Cumbres, 64619 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.57695616,
#   'longitude': -100.2333283,
#   'Route': 0},
#  {'dest_id': 322,
#   'address': 'Avenida Manuel Gómez Morín 2005, Residencial Chipinque 1er Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.55867401,
#   'longitude': -100.2263737,
#   'Route': 0},
#  {'dest_id': 264,
#   'address': 'Avenida Lago de Patzcuaro 5111, Lagos del Bosque, Monterrey, N.L.',
#   'latitude': 25.54939426,
#   'longitude': -100.2172729,
#   'Route': 0},
#  {'dest_id': 675,
#   'address': 'Balcones 300, Predio Residencial Satélite Regiomontano, Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5749784,
#   'longitude': -100.2328851,
#   'Route': 0},
#  {'dest_id': 262,
#   'address': 'Avenida La Vereda 151, Las Colinas Residencial, Monterrey, Nuevo Leon',
#   'latitude': 25.5490994,
#   'longitude': -100.2236849,
#   'Route': 0},
#  {'dest_id': 868,
#   'address': 'Benito Juárez 516, Cabecera Municipal (Apodaca), Apodaca Centro, Ciudad Apodaca, N.L.',
#   'latitude': 25.577861,
#   'longitude': -100.2325711,
#   'Route': 0},
#  {'dest_id': 236,
#   'address': 'Avenida José Vasconcelos 640, 66220 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.54300095,
#   'longitude': -100.2330383,
#   'Route': 0},
#  {'dest_id': 714,
#   'address': 'Baptisterio 104, Valle de San Angel Sector Jardines, 66290 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.57617712,
#   'longitude': -100.2484459,
#   'Route': 0},
#  {'dest_id': 294,
#   'address': 'Avenida Lázaro Cárdenas 436, Valle Oriente, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.555847,
#   'longitude': -100.226302,
#   'Route': 0},
#  {'dest_id': 521,
#   'address': 'Avignon',
#   'latitude': 25.5696763,
#   'longitude': -100.2343296,
#   'Route': 0},
#  {'dest_id': 276,
#   'address': 'Avenida Lázaro Cárdenas 1010, Residencial San Agustín 1er Sector, 66260 San Pedro Garza García, Nuevo León',
#   'latitude': 25.5517758,
#   'longitude': -100.2260813,
#   'Route': 0},
#  {'dest_id': 555,
#   'address': 'Azores 893, Vista Hermosa, 64620 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.57053619,
#   'longitude': -100.2253286,
#   'Route': 0},
#  {'dest_id': 913,
#   'address': 'Berrendo 104, San Patricio 4o Sector, San Pedro Garza García, Nuevo León',
#   'latitude': 25.5787187,
#   'longitude': -100.2391473,
#   'Route': 0},
#  {'dest_id': 533,
#   'address': 'Aviñon, Dominio Cumbres, N.L.',
#   'latitude': 25.570062,
#   'longitude': -100.231198,
#   'Route': 0},
#  {'dest_id': 488,
#   'address': 'Avenida Tlachicuerias 621, Arboledas de Santo Domingo, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.56846978,
#   'longitude': -100.2320226,
#   'Route': 0},
#  {'dest_id': 306,
#   'address': 'Avenida Los Angeles 600, Hacienda El Rosario, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.55661526,
#   'longitude': -100.2264342,
#   'Route': 0},
#  {'dest_id': 538,
#   'address': 'Ayllon 1015, Monterrey, Nuevo Leon ',
#   'latitude': 25.5701459,
#   'longitude': -100.2302115,
#   'Route': 0},
#  {'dest_id': 947,
#   'address': 'Blanco 101, Cerradas de Casa Blanca, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.57978968,
#   'longitude': -100.2489895,
#   'Route': 0},
#  {'dest_id': 424,
#   'address': 'Avenida Ricardo Margain Zozaya 214, Santa Engracia, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.565892,
#   'longitude': -100.229984,
#   'Route': 0},
#  {'dest_id': 363,
#   'address': 'Avenida Oriente 533, Villas de Casa Blanca 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.562227,
#   'longitude': -100.2439841,
#   'Route': 0},
#  {'dest_id': 301,
#   'address': 'Avenida Lomas del Valle 645, Lomas del Valle, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.556304,
#   'longitude': -100.22621,
#   'Route': 0},
#  {'dest_id': 828,
#   'address': 'Bellagio,313,cerradas de santa rosa  66632',
#   'latitude': 25.5772536,
#   'longitude': -100.2421853,
#   'Route': 0},
#  {'dest_id': 785,
#   'address': 'Bavaria 2805, Rincón de Alta Vista, 64844 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5768698,
#   'longitude': -100.2486251,
#   'Route': 0},
#  {'dest_id': 765,
#   'address': 'Barranquilla 126, Alta Vista, 64840 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.57673397,
#   'longitude': -100.2486923,
#   'Route': 0},
#  {'dest_id': 946,
#   'address': 'Blanco 101, Cerradas de Casa Blanca, San Nicolás de los Garza, N.L.',
#   'latitude': 25.57978968,
#   'longitude': -100.2489895,
#   'Route': 0},
#  {'dest_id': 425,
#   'address': 'Avenida Ricardo Margain Zozaya 271, Santa Engracia, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5659192,
#   'longitude': -100.2240794,
#   'Route': 0},
#  {'dest_id': 613,
#   'address': 'BAHIA DE GUANTANAMO 3425 COLONIA RINCON DE LA PRIMAVERA  , MONTERREY ',
#   'latitude': 25.5731625,
#   'longitude': -100.2268782,
#   'Route': 0},
#  {'dest_id': 673,
#   'address': 'Balcones 300, Predio Residencial Satélite Regiomontano, Monterrey, N.L., México, Monterrey',
#   'latitude': 25.574884,
#   'longitude': -100.239404,
#   'Route': 0},
#  {'dest_id': 817,
#   'address': 'Belisario Domínguez 2475, Centro, 64000 Monterrey, N.L.',
#   'latitude': 25.5772073,
#   'longitude': -100.2327771,
#   'Route': 0},
#  {'dest_id': 1088,
#   'address': 'Bolivia 519,Vista Hermosa,Monterrey,Nuevo León,México',
#   'latitude': 25.5864749,
#   'longitude': -100.2422399,
#   'Route': 0},
#  {'dest_id': 320,
#   'address': 'Avenida Manuel Gómez Morín 2005, Residencial Chipinque 1er Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.55845835,
#   'longitude': -100.2260883,
#   'Route': 0},
#  {'dest_id': 654,
#   'address': 'BALCÓN DE LA PEÑA 2902 ALTOS, BALCONES DE ALTA VISTA, 64770 MONTERREY NL, Mexico',
#   'latitude': 25.5744354,
#   'longitude': -100.236355,
#   'Route': 0},
#  {'dest_id': 1087,
#   'address': 'Bolivia 519, vista hermosa, Monterrey N.L',
#   'latitude': 25.586393,
#   'longitude': -100.242166,
#   'Route': 0},
#  {'dest_id': 736,
#   'address': 'Barcelona 503, Valles de Linda Vista, Guadalupe, N.L., México',
#   'latitude': 25.57663145,
#   'longitude': -100.2485163,
#   'Route': 0},
#  {'dest_id': 251,
#   'address': 'Avenida Juan Pablo II 245, Sin Nombre de Colonia 2, Las Puentes 2do Sector, Monterrey, N.L., México',
#   'latitude': 25.5473754,
#   'longitude': -100.2342369,
#   'Route': 0},
#  {'dest_id': 544,
#   'address': 'Azafrán 136, Privadas del Sauce, General Escobedo, N.L.',
#   'latitude': 25.5704114,
#   'longitude': -100.2306684,
#   'Route': 0},
#  {'dest_id': 355,
#   'address': 'Avenida Netzahualcóyotl 672, Ciudad del Sol, Zapopan, Jal.',
#   'latitude': 25.5613913,
#   'longitude': -100.2288359,
#   'Route': 0},
#  {'dest_id': 669,
#   'address': 'BALCONES 1316 BALCONES DE COLINAS SAN JERONIMO MTY, N.L',
#   'latitude': 25.5748015,
#   'longitude': -100.235106,
#   'Route': 0},
#  {'dest_id': 489,
#   'address': 'Avenida torres norte 300 bosques la huasteca, santa catarina nl',
#   'latitude': 25.5685312,
#   'longitude': -100.2353296,
#   'Route': 0},
#  {'dest_id': 1013,
#   'address': 'Blvd. Interamerican 201, Parque Industrial FINSA, 66600 Apodaca, N.L., México',
#   'latitude': 25.58317801,
#   'longitude': -100.2434979,
#   'Route': 0},
#  {'dest_id': 1091,
#   'address': 'Bonampak 629, Balcones de Anáhuac, 66422 San Nicolás de los Garza, N.L.',
#   'latitude': 25.58649249,
#   'longitude': -100.2411152,
#   'Route': 0},
#  {'dest_id': 391,
#   'address': 'Avenida Pico Bolívar 1201, Las Puentes 1 1ro Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5639531,
#   'longitude': -100.2265007,
#   'Route': 0},
#  {'dest_id': 284,
#   'address': 'Avenida Lázaro Cárdenas 2400, Valle Oriente, San Pedro Garza García, N.L.',
#   'latitude': 25.55438797,
#   'longitude': -100.2206461,
#   'Route': 0},
#  {'dest_id': 1118,
#   'address': 'Borrely 317, Nuevo León',
#   'latitude': 25.5868277,
#   'longitude': -100.2388545,
#   'Route': 0},
#  {'dest_id': 522,
#   'address': 'Ávila 390, Gonzalitos, 64020 Monterrey, N.L., México',
#   'latitude': 25.5696835,
#   'longitude': -100.2359141,
#   'Route': 0},
#  {'dest_id': 275,
#   'address': 'Avenida Las Torres 3307, Camino Real, Guadalupe, Nuevo Leon',
#   'latitude': 25.55177574,
#   'longitude': -100.2260813,
#   'Route': 0},
#  {'dest_id': 548,
#   'address': 'Azores',
#   'latitude': 25.57047208,
#   'longitude': -100.236613,
#   'Route': 0},
#  {'dest_id': 510,
#   'address': 'Avenida Vista Real 543, Valle Oriente, 66266 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.5694908,
#   'longitude': -100.2313602,
#   'Route': 0},
#  {'dest_id': 307,
#   'address': 'Avenida los Encinos 205, Los Encinos, Juárez, Nuevo Leon',
#   'latitude': 25.5566556,
#   'longitude': -100.2283257,
#   'Route': 0},
#  {'dest_id': 790,
#   'address': 'Beethoven 1032, Misión de Anáhuac, 66059 Cd Gral Escobedo, N.L., México, Ciudad General Escobedo',
#   'latitude': 25.5768698,
#   'longitude': -100.2486251,
#   'Route': 0},
#  {'dest_id': 333,
#   'address': 'Avenida Manuel L. Barragán 6512, Valle de Anáhuac, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5597,
#   'longitude': -100.254831,
#   'Route': 0},
#  {'dest_id': 558,
#   'address': 'Azucena 118, Miraflores, 66410 San Nicolás de los Garza, N.L., México, San Nicolás de los Garza',
#   'latitude': 25.57073415,
#   'longitude': -100.2297631,
#   'Route': 0},
#  {'dest_id': 428,
#   'address': 'Avenida Rio Nilo 433, Misión de Huinala, Ciudad Apodaca, Nuevo Leon',
#   'latitude': 25.566058,
#   'longitude': -100.230633,
#   'Route': 0},
#  {'dest_id': 769,
#   'address': 'Basalto 4812, Villa Dorada, 64360 Monterrey, N.L., México',
#   'latitude': 25.5767373,
#   'longitude': -100.2487014,
#   'Route': 0},
#  {'dest_id': 467,
#   'address': 'Avenida Santa Barbara 264, Zona Los Callejones, Monterrey, Nuevo León',
#   'latitude': 25.5675248,
#   'longitude': -100.2570827,
#   'Route': 0},
#  {'dest_id': 709,
#   'address': 'Bambú 700, Paseo de Las Palmas, Ciudad Apodaca, Nuevo Leon',
#   'latitude': 25.5761098,
#   'longitude': -100.2327796,
#   'Route': 0},
#  {'dest_id': 749,
#   'address': 'Barisan, Santa Catarina, N.L.',
#   'latitude': 25.57665504,
#   'longitude': -100.2484975,
#   'Route': 0},
#  {'dest_id': 1107,
#   'address': 'Borbon 216, Pedregal de La Huasteca, 66354 Santa Catarina, N.L., México',
#   'latitude': 25.5866441,
#   'longitude': -100.242701,
#   'Route': 0},
#  {'dest_id': 437,
#   'address': 'Avenida Roberto Garza Sada 207, Zona Tampiquito, Balcones del Valle, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.566486,
#   'longitude': -100.22612,
#   'Route': 0},
#  {'dest_id': 920,
#   'address': 'Betica 12, Cordillera, Santa Catarina, Nuevo Leon',
#   'latitude': 25.57881892,
#   'longitude': -100.2430867,
#   'Route': 0},
#  {'dest_id': 304,
#   'address': 'Avenida Los Amarantos 329, Los Amarantos, Apodaca, N.L.',
#   'latitude': 25.5564187,
#   'longitude': -100.2260736,
#   'Route': 0},
#  {'dest_id': 369,
#   'address': 'Avenida Pablo Livas 4010, Rafael Ramírez (U.p.), 67180 Guadalupe, N.L.\n',
#   'latitude': 25.5626445,
#   'longitude': -100.2321093,
#   'Route': 0},
#  {'dest_id': 486,
#   'address': 'Avenida Tlachicuerias 1014, Los Naranjos 1er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.56839448,
#   'longitude': -100.230145,
#   'Route': 0},
#  {'dest_id': 1005,
#   'address': 'Blvd. Díaz Ordaz 26, San Jeronimo, 64660 Monterrey, N.L., México',
#   'latitude': 25.5824096,
#   'longitude': -100.2437577,
#   'Route': 0},
#  {'dest_id': 987,
#   'address': 'Blvd. Botánica 407, Valle del Campestre, 66266 San Pedro Garza García, N.L. En arboleda, torre cassea dpto. 1801',
#   'latitude': 25.5814476,
#   'longitude': -100.2463434,
#   'Route': 0},
#  {'dest_id': 1115,
#   'address': 'BORRELY 309, COLONIA PRIVADA ALDRIN CASTELLANIA ',
#   'latitude': 25.586822,
#   'longitude': -100.2410415,
#   'Route': 0},
#  {'dest_id': 851,
#   'address': 'Benito Juárez 103, Barrio Tampiquito, Lomas de Tampiquito, San Pedro Garza García, N.L., México',
#   'latitude': 25.5776486,
#   'longitude': -100.242503,
#   'Route': 0},
#  {'dest_id': 328,
#   'address': 'Avenida Manuel Gómez Morín 404, 66266, San Pedro Garza García, Mexico',
#   'latitude': 25.55922134,
#   'longitude': -100.220712,
#   'Route': 0},
#  {'dest_id': 587,
#   'address': 'Bachilleres 103, Tecnológico, Monterrey, Nuevo Leon',
#   'latitude': 25.5718664,
#   'longitude': -100.2373532,
#   'Route': 0},
#  {'dest_id': 605,
#   'address': 'Bahía Blanca 3742, Rincon De La Primavera, Monterrey, Nuevo Leon',
#   'latitude': 25.57260696,
#   'longitude': -100.2381553,
#   'Route': 0},
#  {'dest_id': 822,
#   'address': 'Belisario Domínguez 527 a, Floridos Bosques del Nogalar, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.577236,
#   'longitude': -100.2429264,
#   'Route': 0},
#  {'dest_id': 782,
#   'address': 'Batallones Rojos 5949, Paso del Aguila, 64145 Monterrey, N.L.',
#   'latitude': 25.5768698,
#   'longitude': -100.2486251,
#   'Route': 0},
#  {'dest_id': 335,
#   'address': 'Avenida Manuel Ordoñez 335, Centro, Santa Catarina, N.L.',
#   'latitude': 25.5597002,
#   'longitude': -100.2548306,
#   'Route': 0},
#  {'dest_id': 326,
#   'address': 'Avenida Manuel Gómez Morín 285, Valle del Campestre, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.55922117,
#   'longitude': -100.2207118,
#   'Route': 0},
#  {'dest_id': 231,
# ...
#  {'dest_id': 1481,
#   'address': 'Boticelli 200, Renacimiento, Colonia Miguel Hidalgo, Monterrey, N.L.',
#   'latitude': 25.60145521,
#   'longitude': -100.2719521,
#   'Route': 4},
#  {'dest_id': 620,
#   'address': 'Bahía de Vizcaíno 4308, Las Brisas 4o. Sector, 64780 Monterrey, N.L.',
#   'latitude': 25.5736759,
#   'longitude': -100.2807016,
#   'Route': 4},
#  {'dest_id': 634,
#   'address': 'Bahía Grande 3752, Rincon De La Primavera, 64835 Monterrey, N.L., México',
#   'latitude': 25.573815,
#   'longitude': -100.274359,
#   'Route': 4},
#  {'dest_id': 891,
#   'address': 'Bermudas 147, Vista Hermosa, Monterrey, Nuevo Leon',
#   'latitude': 25.57826292,
#   'longitude': -100.2619434,
#   'Route': 4},
#  {'dest_id': 1716,
#   'address': 'C. SAN GERARDO 314 314 314 314, RESIDENIAL CALIFORNIA, ESCOBEDO',
#   'latitude': 25.606169,
#   'longitude': -100.265117,
#   'Route': 4},
#  {'dest_id': 846,
#   'address': 'Benito Juarez  2211, 15 de Mayo (Larralde), 64450, Monterrey',
#   'latitude': 25.5775376,
#   'longitude': -100.2694489,
#   'Route': 4},
#  {'dest_id': 1539,
#   'address': 'Brasil 304, Vista Hermosa, Monterrey, Nuevo Leon',
#   'latitude': 25.60327359,
#   'longitude': -100.2558008,
#   'Route': 4},
#  {'dest_id': 1461,
#   'address': 'Bosques el Edén #203,Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.6009914,
#   'longitude': -100.2538876,
#   'Route': 4},
#  {'dest_id': 1402,
#   'address': 'bosques de saigon,Bosques del Valle,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.5988545,
#   'longitude': -100.2552405,
#   'Route': 4},
#  {'dest_id': 1387,
#   'address': 'Bosques de Primavera 222, Cima del Bosque, Nuevo Leon',
#   'latitude': 25.59827979,
#   'longitude': -100.2680374,
#   'Route': 4},
#  {'dest_id': 588,
#   'address': 'Bachilleres 117, Tecnológico, 64700 Monterrey, N.L.',
#   'latitude': 25.5719661,
#   'longitude': -100.2780463,
#   'Route': 4},
#  {'dest_id': 1159,
#   'address': 'Bosque de Cenizos 219, Cima del Bosque, Nuevo Leon',
#   'latitude': 25.58935509,
#   'longitude': -100.2577592,
#   'Route': 4},
#  {'dest_id': 1415,
#   'address': 'Bosques de Tahiti 525, Bosques del Valle 3ER Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.59960265,
#   'longitude': -100.2662708,
#   'Route': 4},
#  {'dest_id': 1373,
#   'address': 'Bosques de Palmas 512-443, 66362 Santa Catarina, N.L.',
#   'latitude': 25.59791787,
#   'longitude': -100.2707984,
#   'Route': 4},
#  {'dest_id': 1067,
#   'address': 'Boca Ratón 118, Sin Nombre de Col 51, Monterrey, N.L.',
#   'latitude': 25.5858743,
#   'longitude': -100.2738852,
#   'Route': 4},
#  {'dest_id': 1678,
#   'address': 'Bustamante 140, Valle de San Agustín, 66278 San Pedro Garza García, N.L.',
#   'latitude': 25.6055582,
#   'longitude': -100.2636247,
#   'Route': 4},
#  {'dest_id': 442,
#   'address': 'Avenida Roberto Garza Sada 900, Carrizalejo, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.5665399,
#   'longitude': -100.2750638,
#   'Route': 4},
#  {'dest_id': 1243,
#   'address': 'Bosques de Chapultepec 409, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5942906,
#   'longitude': -100.2485137,
#   'Route': 4},
#  {'dest_id': 594,
#   'address': 'Bagdad  66480 1227, Bosques del Nogalar, Calle Bagdad, Bosques del Nogalar, San Nicolás de los Garza, N.L., México',
#   'latitude': 25.57216,
#   'longitude': -100.271969,
#   'Route': 4},
#  {'dest_id': 1469,
#   'address': 'Bosques Mexicanos 122, Zona Bosques del Valle, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.6011724,
#   'longitude': -100.2738699,
#   'Route': 4},
#  {'dest_id': 1568,
#   'address': 'Brest 230, Bosques de Las Cumbres, 64619 Monterrey, N.L., México',
#   'latitude': 25.60398502,
#   'longitude': -100.2565291,
#   'Route': 4},
#  {'dest_id': 423,
#   'address': 'Avenida Ricardo Margain Zozaya 150, Privada Santa Engracia, 66267 San Pedro Garza García, N.L.',
#   'latitude': 25.565811,
#   'longitude': -100.276175,
#   'Route': 4},
#  {'dest_id': 672,
#   'address': 'Balcones 300, Predio Residencial Satélite Regiomontano, Monterrey, N.L., Mexico',
#   'latitude': 25.57487881,
#   'longitude': -100.2737073,
#   'Route': 4},
#  {'dest_id': 1120,
#   'address': 'Borrely, Nuevo León, México',
#   'latitude': 25.5869536,
#   'longitude': -100.2446223,
#   'Route': 4},
#  {'dest_id': 419,
#   'address': 'Avenida Revolución 2703, Sin Nombre de Colonia 45, Monterrey, Nuevo Leon',
#   'latitude': 25.5655247,
#   'longitude': -100.2708837,
#   'Route': 4},
#  {'dest_id': 599,
#   'address': 'Bahía Algeciras 3306A, Rincon De La Primavera, 64835 Monterrey, N.L.',
#   'latitude': 25.57242,
#   'longitude': -100.277682,
#   'Route': 4},
#  {'dest_id': 1215,
#   'address': 'BOSQUES',
#   'latitude': 25.5925615,
#   'longitude': -100.2783047,
#   'Route': 4},
#  {'dest_id': 586,
#   'address': 'Bachilleres 103, Tecnológico, 64700 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.571847,
#   'longitude': -100.273483,
#   'Route': 4},
#  {'dest_id': 585,
#   'address': 'B. de Los Encinos 401, Bosques de Anáhuac, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.5718465,
#   'longitude': -100.2734828,
#   'Route': 4},
#  {'dest_id': 1584,
#   'address': 'Brisa del Rio 101, Valle Alto, Monterrey, Nuevo León',
#   'latitude': 25.60417839,
#   'longitude': -100.2564632,
#   'Route': 4},
#  {'dest_id': 1673,
#   'address': 'Burgos 6605, Cumbres de Santa Clara, 64349 Monterrey, N.L., México',
#   'latitude': 25.6055276,
#   'longitude': -100.2595182,
#   'Route': 4},
#  {'dest_id': 1001,
#   'address': 'Blvd. Díaz Ordaz 120, Santa María, 64650 Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5822667,
#   'longitude': -100.2607091,
#   'Route': 4},
#  {'dest_id': 1519,
#   'address': 'Boulevard Puerta del Sol 602, Colinas de San Jerónimo 1o. Sector, Monterrey, Nuevo Leon',
#   'latitude': 25.602725,
#   'longitude': -100.2744468,
#   'Route': 4},
#  {'dest_id': 1345,
#   'address': 'Bosques de Los Pirineos 213, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L., México, San Pedro Garza García',
#   'latitude': 25.5974002,
#   'longitude': -100.26833,
#   'Route': 4},
#  {'dest_id': 707,
#   'address': 'Bambú 1603, Sin Nombre de Col 50, Monterrey, N.L., México, Monterrey',
#   'latitude': 25.5760376,
#   'longitude': -100.2662318,
#   'Route': 4},
#  {'dest_id': 1426,
#   'address': 'Bosques del Alamo 306, Bosques del Valle 1er Sector, San Pedro Garza García, N.L.',
#   'latitude': 25.60027587,
#   'longitude': -100.2596382,
#   'Route': 4},
#  {'dest_id': 1239,
#   'address': 'Bosques de Chapultepec 304, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5940886,
#   'longitude': -100.2462218,
#   'Route': 4},
#  {'dest_id': 685,
#   'address': 'Balcones de la Colina 5316, Monterrey, 64790, Balcones del Mirador',
#   'latitude': 25.575292,
#   'longitude': -100.259068,
#   'Route': 4},
#  {'dest_id': 1704,
#   'address': 'C. Lago Nicaragua 6917, Lagos del Bosque, 64890 Monterrey, N.L., México',
#   'latitude': 25.60604419,
#   'longitude': -100.2779453,
#   'Route': 4},
#  {'dest_id': 1011,
#   'address': 'Blvd. Díaz Ordaz 316, Santa María, Monterrey, Nuevo Leon',
#   'latitude': 25.58262007,
#   'longitude': -100.2480415,
#   'Route': 4},
#  {'dest_id': 1232,
#   'address': 'Bosques de Canadá 205, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5937859,
#   'longitude': -100.2474605,
#   'Route': 4},
#  {'dest_id': 1586,
#   'address': 'Brisa del Río 111, Brisas de Valle Alto, Monterrey',
#   'latitude': 25.6041823,
#   'longitude': -100.2741223,
#   'Route': 4},
#  {'dest_id': 1044,
#   'address': 'Blvd. Puerta del Sol 726, Colinas de San Jerónimo 4o. Sector, Monterrey, N.L., México',
#   'latitude': 25.5842225,
#   'longitude': -100.2773523,
#   'Route': 4},
#  {'dest_id': 1350,
#   'address': 'Bosques de Los Pirineos 502, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.597432,
#   'longitude': -100.2633862,
#   'Route': 4},
#  {'dest_id': 1649,
#   'address': 'Burdeos 207, Cerradas de Concordia, 66609 Cd Apodaca, N.L., México',
#   'latitude': 25.6052241,
#   'longitude': -100.2761599,
#   'Route': 4},
#  {'dest_id': 1370,
#   'address': 'Bosques de Olmos 26, Villas del Valle, San Pedro Garza García, N.L.',
#   'latitude': 25.5978592,
#   'longitude': -100.2580263,
#   'Route': 4},
#  {'dest_id': 1424,
#   'address': 'Bosques de Vistancia, Sierra de la Silla, Villas La Rioja, Monterrey, Nuevo Leon',
#   'latitude': 25.60026135,
#   'longitude': -100.25983,
#   'Route': 4},
#  {'dest_id': 1364,
#   'address': 'Bosques de Olmos 17, Villas del Valle, 66288 San Pedro Garza García, N.L., Mexico',
#   'latitude': 25.59775625,
#   'longitude': -100.2685506,
#   'Route': 4},
#  {'dest_id': 1533,
#   'address': 'Brasa 333, Parque la Talaverna, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.6031515,
#   'longitude': -100.2644598,
#   'Route': 4},
#  {'dest_id': 430,
#   'address': 'Avenida Roberto Garza Sada 1000, Zona Residencial Chipinque, San Pedro Garza García, N.L. Departamento 305',
#   'latitude': 25.5660599,
#   'longitude': -100.2736854,
#   'Route': 4},
#  {'dest_id': 1314,
#   'address': 'bosques de la silla 2501-22,Bosques de la Pastora,Guadalupe,Nuevo León,México',
#   'latitude': 25.5962625,
#   'longitude': -100.2694112,
#   'Route': 4},
#  {'dest_id': 1386,
#   'address': 'Bosques de Pirineos 520, Bosques del Valle 3ER Sector, San Pedro Garza García, N.L. Dpto 3',
#   'latitude': 25.598248,
#   'longitude': -100.267708,
#   'Route': 4},
#  {'dest_id': 1566,
#   'address': 'Brest 227, Bosques de Las Cumbres, 64619 Monterrey, N.L., México',
#   'latitude': 25.6039554,
#   'longitude': -100.252146,
#   'Route': 4},
#  {'dest_id': 537,
#   'address': 'AYLLON 1009 COLONIA RESIDENCIAL DE LA SIERRA , MONTERREY ',
#   'latitude': 25.570141,
#   'longitude': -100.274902,
#   'Route': 4},
#  {'dest_id': 1672,
#   'address': 'Burgos 4147, Las Torres, Monterrey, Nuevo Leon',
#   'latitude': 25.6055234,
#   'longitude': -100.2643831,
#   'Route': 4},
#  {'dest_id': 1275,
#   'address': 'Bosques de Cuernavaca 518, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.5949978,
#   'longitude': -100.2522207,
#   'Route': 4},
#  {'dest_id': 1322,
#   'address': 'Bosques de Los Alamos 415, Bosques de Anáhuac, San Nicolás de los Garza, N.L., México',
#   'latitude': 25.5966266,
#   'longitude': -100.2504041,
#   'Route': 4},
#  {'dest_id': 1410,
#   'address': 'Bosques de Siberia 204, Bosques del Valle 1er Sector, 66250 San Pedro Garza García, N.L., Mexico, San Pedro Garza García',
#   'latitude': 25.5992465,
#   'longitude': -100.2624068,
#   'Route': 4},
#  {'dest_id': 1084,
#   'address': 'Bolivia 432, Vista Hermosa, Monterrey, Nuevo Leon',
#   'latitude': 25.58638242,
#   'longitude': -100.2758807,
#   'Route': 4},
#  {'dest_id': 978,
#   'address': 'Blvd. Antonio L. Rodríguez 2100 Edificio BH Piso 11 Int 116, Privada Sta. María, 64650 Monterrey, N.L., Mexico',
#   'latitude': 25.5809169,
#   'longitude': -100.2623021,
#   'Route': 4},
#  {'dest_id': 1427,
#   'address': 'Bosques del Canadá 628, Bosques de Anáhuac, 66463 San Nicolás de los Garza, N.L.',
#   'latitude': 25.60029461,
#   'longitude': -100.2567891,
#   'Route': 4},
#  {'dest_id': 1033,
#   'address': 'Blvd. Puerta del Sol 612, Colinas de San Jerónimo 1o. Sector, Monterrey, N.L., México',
#   'latitude': 25.58392239,
#   'longitude': -100.2534574,
#   'Route': 4},
#  {'dest_id': 1191,
#   'address': 'Bosque Kasajo 429, Las Lomas Sector Bosques, Villas del Poniente, N.L., México',
#   'latitude': 25.59114522,
#   'longitude': -100.2790633,
#   'Route': 4},
#  {'dest_id': 1276,
#   'address': 'Bosques de Cuernavaca 525, Bosques del Valle 3ER Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.5949978,
#   'longitude': -100.2522207,
#   'Route': 4},
#  {'dest_id': 1661,
#   'address': 'Burgos 3805,Las Torres,Monterrey,Nuevo León,México',
#   'latitude': 25.60542996,
#   'longitude': -100.2531143,
#   'Route': 4},
#  {'dest_id': 1291,
#   'address': 'Bosques de La Huasteca 307, Bosques del Valle 4to Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.595531,
#   'longitude': -100.247693,
#   'Route': 4},
#  {'dest_id': 1715,
#   'address': 'C. Puerto Soconusco 5412, Las Brisas 8o. Sector, 64780 Monterrey, N.L., México',
#   'latitude': 25.6061689,
#   'longitude': -100.2651168,
#   'Route': 4},
#  {'dest_id': 935,
#   'address': 'Bioma Residencial, Camino Al Diente 198, Bioma Residencial, Monterrey, Nuevo Leon',
#   'latitude': 25.579286,
#   'longitude': -100.2668273,
#   'Route': 4},
#  {'dest_id': 966,
#   'address': 'Blvd. Acapulco 800, Josefa Zozaya, 67110 Guadalupe, N.L., México',
#   'latitude': 25.58042972,
#   'longitude': -100.2632896,
#   'Route': 4},
#  {'dest_id': 1351,
#   'address': 'Bosques de Los Pirineos 502, Bosques del Valle 3ER Sector, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.59743212,
#   'longitude': -100.2672778,
#   'Route': 4},
#  {'dest_id': 1659,
#   'address': 'Burgos 3804, Las Torres, 64930 Monterrey, N.L.',
#   'latitude': 25.6053516,
#   'longitude': -100.2624442,
#   'Route': 4},
#  {'dest_id': 1240,
#   'address': 'Bosques de Chapultepec 310, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L., México',
#   'latitude': 25.59415605,
#   'longitude': -100.2658772,
#   'Route': 4},
#  {'dest_id': 1224,
#   'address': 'Bosques de Alamos 564, Bosques del Poniente, 66362 Santa Catarina, N.L., México',
#   'latitude': 25.5932022,
#   'longitude': -100.2816229,
#   'Route': 4},
#  {'dest_id': 1002,
#   'address': 'Blvd. Díaz Ordaz 130, Santa María, 64650 Monterrey, N.L.',
#   'latitude': 25.5823071,
#   'longitude': -100.2485521,
#   'Route': 4},
#  {'dest_id': 1554,
#   'address': 'Brest 115, Bosques de Las Cumbres, 64619 Monterrey, N.L.',
#   'latitude': 25.60353589,
#   'longitude': -100.2630782,
#   'Route': 4},
#  {'dest_id': 1588,
#   'address': 'Briviesca',
#   'latitude': 25.6041932,
#   'longitude': -100.2630251,
#   'Route': 4},
#  {'dest_id': 1129,
#   'address': 'Bosque Andaluz 516, Las Lomas Sector Bosques, N.L., México',
#   'latitude': 25.5870958,
#   'longitude': -100.2607587,
#   'Route': 4},
#  {'dest_id': 997,
#   'address': 'Blvd. de la Reina 219, Arboledas de la Luz, León, Gto., México',
#   'latitude': 25.58210569,
#   'longitude': -100.2485012,
#   'Route': 4},
#  {'dest_id': 1433,
#   'address': 'Bosques del Eden 215, Bosques del Valle 2o Sector, 66250 San Pedro Garza García, N.L.',
#   'latitude': 25.60038244,
#   'longitude': -100.2680525,
#   'Route': 4},
#  {'dest_id': 1137,
#   'address': 'Bosque de Abetos 627, Bosques de Santa Catarina, Bosques de Sta Catarina, Santa Catarina, N.L.',
#   'latitude': 25.58752,
#   'longitude': -100.250948,
#   'Route': 4},
#  {'dest_id': 1237,
#   'address': 'Bosques de Chapultepec 204, Bosques del Valle, San Pedro Garza Garcia',
#   'latitude': 25.5939204,
#   'longitude': -100.2473967,
#   'Route': 4},
#  {'dest_id': 4,
#   'address': 'Avenida Circuito Frida Kahlo 2225, Haciendas de La Sierra, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.2744189,
#   'longitude': -100.027226,
#   'Route': 5},
#  {'dest_id': 16,
#   'address': 'Avenida Constituyentes de Nuevo León, Parque Industrial Regiomontano, Monterrey, N.L., México',
#   'latitude': 25.31481171,
#   'longitude': -100.0463691,
#   'Route': 5},
#  {'dest_id': 6,
#   'address': 'Avenida Colonial de la Sierra 311, Colonial de La Sierra, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.2782044,
#   'longitude': -100.0148553,
#   'Route': 5},
#  {'dest_id': 13,
#   'address': 'Avenida Conductores 240, Constituyentes de Queretaro 3er Sector, San Nicolás de los Garza, Nuevo Leon',
#   'latitude': 25.2980443,
#   'longitude': -100.0256941,
#   'Route': 5},
#  {'dest_id': 7,
#   'address': 'Avenida Colonial de la Sierra 318, Colonial de La Sierra, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.27973116,
#   'longitude': -100.0191856,
#   'Route': 5},
#  {'dest_id': 3,
#   'address': 'Avenida Circuito Frida Kahlo 2222, Valle Oriente, San Pedro Garza García, Nuevo Leon',
#   'latitude': 25.2733425,
#   'longitude': -100.0184588,
#   'Route': 5},
#  {'dest_id': 11,
#   'address': 'avenida colonial de la sierra,Colonial La Sierra,San Pedro Garza García,Nuevo León,México',
#   'latitude': 25.2846257,
#   'longitude': -100.0239934,
#   'Route': 5},
#  {'dest_id': 8,
#   'address': 'Avenida Colonial de la Sierra 335, Colonial de La Sierra, San Pedro Garza García, N.L., México',
#   'latitude': 25.2798363,
#   'longitude': -100.0295155,
#   'Route': 5}]

# %%
# Plot the predicted clusters to see if the model predicted the correct clusters
# This is visual validation that the model was trained correctly.
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
